# %%
import re
import spacy
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO

# %%
def extract_text_from_pdf(pdf_path):
    # Initialize the PDF resource manager
    rsrcmgr = PDFResourceManager()
    # Initialize the StringIO object to store the text
    output = StringIO()
    # Initialize the TextConverter object
    device = TextConverter(rsrcmgr, output, laparams=LAParams())
    # Initialize the PDFPageInterpreter object
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    # Open the PDF file
    with open(pdf_path, 'rb') as f:
        # Iterate over the pages of the PDF
        for page in PDFPage.get_pages(f):
            # Process the page
            interpreter.process_page(page)
    # Close the TextConverter object
    device.close()
    # Get the text from the StringIO object
    text = output.getvalue()
        # Lowercase the text
    text = text.lower()
    # Close the StringIO object
    output.close()
    # Return the text
    return text
text= extract_text_from_pdf("Survey_on_Device_to_Device_D2D_Communication_for_5GB.pdf")

# %%
 text
# Out:
# 'received march 1, 2022, accepted march 14, 2022, date of publication march 16, 2022, date of current version march 24, 2022.\n\ndigital object identifier 10.1109/access.2022.3160215\n\nsurvey on device to device (d2d) communication\nfor 5gb/6g networks: concept, applications,\nchallenges, and future directions\n\nmohammed salih mohammed gismalla 1,2,3, (senior member, ieee),\nasrul izam azmi 1,2, (member, ieee), mohd rashidi bin salim1,2, (member, ieee),\nmohammad faiz liew abdullah 4, (senior member, ieee), farabi iqbal1,2,\nwafi a. mabrouk 4, (graduate student member, ieee),\nmaisara binti othman4, (member, ieee), adel y. i. ashyap 4,\nand abu sahmah mohd supa’at1,2\n1school of electrical engineering, faculty of engineering, universiti teknologi malaysia, skudai 81310, malaysia\n2lightwave communications research group (lcrg), innovative engineering research alliance, universiti teknologi malaysia, johor bahru 81310, malaysia\n3department of electronics and electrical engineering, faculty of engineering, international university of africa, khartoum 12223, sudan\n4department of communication engineering, faculty of electrical and electronic engineering, universiti tun hussein onn malaysia (uthm), parit raja, batu\npahat, johor 86400, malaysia\ncorresponding authors: mohammed salih mohammed gismalla (salihmohammed@utm.my) and abu sahmah mohd supa’at\n(abus@utm.my)\n\nthis work was supported in part by the research management centre (rmc), universiti teknologi malaysia (utm), malaysia, under the\nprofessional development research university grant 05e69; and in part by utm under tdr grant 05g27.\n\nabstract device-to-device (d2d) communication is one of the most promising technologies in wireless\ncellular networks that can be employed to improve spectral and energy efﬁciency, increase data rates, and\nreduce links latency. this paper investigates ﬁfth generation and beyond (5gb) networks, the basics of\nd2d communication, applications, and classiﬁcation. herein, d2d in in-band (ibd) and out-band (obd)\nmodes are discussed. this paper also presents the integration of d2d communication with other prominent\ntechnologies and demonstrates the importance of integration with possible solutions in improving network\nperformance. we further investigate the challenges of d2d communication, opportunities, and future\nresearch directions of d2d in 5gb networks. in addition, d2d communication in 6g network challenges\nand open research areas are introduced.\n\nindex terms 5g, 5gb, 6g, d2d communication, millimeter wave (mm-wave), visible light communi-\ncation (vlc), ultra-dense network (udn), and unmanned aerial vehicle (uav).\n\ni. introduction\nmobile wireless communication demands for higher data\nrates, lower energy consumption, low latency, coverage area,\nas well as efﬁcient spectrum sharing are rapidly increasing\nday by day. the number of connected devices is estimated\nto be over 50 billion in the year 2020 [1]–[3], in which\nmobile data trafﬁc is projected to grow monthly from 13.8 in\n2017 to 110 exabytes (eb) till the end of 2023 at a compound\nannual growth rate (cagr) of 42% based on the ericsson\nreport [4]. all these issues should be resolved to provide and\nsupport the demands of the upcoming ﬁfth-generation (5g)\n\nthe associate editor coordinating the review of this manuscript and\n\napproving it for publication was stefano scanzio\n\n.\n\nand beyond (5gb). 5g was expected to launch in 2020 with\na very high data rate and quality of services (qos), and\nit aims to offer a 1000-fold rise in the total throughput.\nmoreover, in order to achieve a ten-fold increase in indi-\nvidual link throughput over the previous fourth-generation\n(4g) wireless networks [5], [6], various technologies are\nsuggested to be considered in order to fulﬁll 5gb require-\nments such as an ultra-dense network (udn) with machine-\nto-machine (m2m) in heterogeneous networks, in addition to\nmillimeter-wave (mm-wave), massive mimo, virtualization\n ...

# %%
def tokenizer(text):
    nlp = spacy.load('en_core_web_sm')
    # Tokenize the text into sentences and words
    doc = nlp(''.join(text))
    sentences = [sent.text for sent in doc.sents]
    words = [word.text for word in doc]
    return (sentences,words)
sentences, words = tokenizer(text)

# %%
sentences
# Out:
# ['received march 1, 2022, accepted march 14, 2022, date of publication march 16, 2022, date of current version march 24, 2022.\n\n',
#  'digital object identifier 10.1109/access.2022.3160215\n\nsurvey on device to device (d2d) communication\nfor 5gb/6g networks: concept, applications,\nchallenges, and future directions\n\nmohammed salih mohammed gismalla 1,2,3, (senior member, ieee),\nasrul izam azmi 1,2, (member, ieee), mohd rashidi bin salim1,2, (member, ieee),\n',
#  'mohammad faiz liew abdullah 4, (senior member, ieee), farabi iqbal1,2,\nwafi a. mabrouk 4, (graduate student member, ieee),\nmaisara binti othman4, (member, ieee), adel y. i. ashyap 4,\nand abu sahmah mohd supa’at1,2\n1school of electrical engineering, faculty of engineering, universiti teknologi malaysia, skudai 81310, malaysia\n2lightwave communications research group (lcrg), innovative engineering research alliance, universiti teknologi malaysia, johor bahru 81310, malaysia\n3department of electronics and electrical engineering, faculty of engineering, international university of africa, khartoum 12223, sudan\n4department of communication engineering, faculty of electrical and electronic engineering, universiti tun hussein onn malaysia (uthm), parit raja, batu\npahat, johor 86400, malaysia\ncorresponding authors: mohammed salih mohammed gismalla (salihmohammed@utm.my) and abu sahmah mohd supa’at\n(abus@utm.my)\n\nthis work was supported in part by the research management centre (rmc), universiti teknologi malaysia (utm), malaysia, under the\nprofessional development research university grant 05e69; and in part by utm under tdr grant 05g27.\n\n',
#  'abstract device-to-device (d2d) communication is one of the most promising technologies in wireless\ncellular networks that can be employed to improve spectral and energy efﬁciency, increase data rates, and\nreduce links latency.',
#  'this paper investigates ﬁfth generation and beyond (5gb) networks, the basics of\nd2d communication, applications, and classiﬁcation.',
#  'herein, d2d in in-band (ibd) and out-band (obd)\nmodes are discussed.',
#  'this paper also presents the integration of d2d communication with other prominent\ntechnologies and demonstrates the importance of integration with possible solutions in improving network\nperformance.',
#  'we further investigate the challenges of d2d communication, opportunities, and future\nresearch directions of d2d in 5gb networks.',
#  'in addition, d2d communication in 6g network challenges\nand open research areas are introduced.',
#  '\n\n',
#  'index terms 5g, 5gb, 6g, d2d communication, millimeter wave (mm-wave), visible light communi-\ncation (vlc), ultra-dense network (udn), and unmanned aerial vehicle (uav).\n\n',
#  'i. introduction\nmobile wireless communication demands for higher data\nrates, lower energy consumption, low latency, coverage area,\nas well as efﬁcient spectrum sharing are rapidly increasing\nday by day.',
#  'the number of connected devices is estimated\nto be over 50 billion in the year 2020',
#  '[1]–[3], in which\nmobile data trafﬁc is projected to grow monthly from 13.8 in\n2017 to 110 exabytes (eb) till the end of 2023 at a compound\nannual growth rate (cagr) of 42% based on the ericsson\nreport [4].',
#  'all these issues should be resolved to provide and\nsupport the demands of the upcoming ﬁfth-generation (5g)\n\nthe associate editor coordinating the review of this manuscript and\n\napproving it for publication was stefano scanzio\n\n.\n\nand beyond (5gb).',
#  '5g was expected to launch in 2020 with\na very high data rate and quality of services (qos), and\nit aims to offer a 1000-fold rise in the total throughput.\n',
#  'moreover, in order to achieve a ten-fold increase in indi-\nvidual link throughput over the previous fourth-generation\n(4g) wireless networks [5], [6], various technologies are\nsuggested to be considered in order to fulﬁll 5gb require-\nments such as an ultra-dense network (udn) with machine-\nto-machine (m2m) in heterogeneous networks, in addition to\nmillimeter-wave (mm-wave), massive mimo, virtualization\nof wireless resources, visible light communication (vlc),\nenergy harvesting, and cloud-based radio access network\n(c-ran)',
#  '[7].',
#  'a novel physical technology such as vlc\nhas been suggested to deliver high data rates, where a\n\n30792\n\nthis work is licensed under a creative commons attribution 4.0 license.',
#  'for more information, see https://creativecommons.org/licenses/by/4.0/\n\nvolume 10, 2022\n\n\x0cm. s. m. gismalla et',
#  'al.: survey on d2d communication for 5gb/6g networks\n\nfigure 1. developments of mobile radio communication networks generations [5].\n\n',
#  'considerable bandwidth of vlc technology could support\nhigher data rates with up to 100gbps and beyond [8]–[10].\n',
#  'fig.1 illustrates the development of mobile communication\nnetworks, which involves 1g to 5g generations, technolo-\ngies, systems, and standardizations.\n\n',
#  'many techniques and approaches have been implemented\nto cope with the increasing demand for network capacity.\n',
#  'new modulation techniques, signal processing, and spectrum\nallocation techniques were employed to improve spectral efﬁ-\nciency and link capacity.',
#  'however, they require many small\nbase stations in indoor environments in order to meet the\nrequirements of the upcoming 5gb applications, although\nimproving the channel capacity, transmission rate, bit error\nrate (ber) performance as well as signal-to-noise (snr),\ncould increase total spectral efﬁciency and',
#  'bandwidth den-\nsity',
#  '[11], [12].',
#  '\n\naccording to the current and expected requirements of\ncommunication networks, an emerging technology called\ndevice-to-device (d2d) communication has attracted atten-\ntion as a critical key for cellular network performance\nenhancement in 5gb [13], [14].',
#  'd2d communication offers\nmany advantages for cellular networks, namely; (i) higher\ntransmission rate, (ii) enhancing energy efﬁciency, (iii)\nofﬂoading the overloaded cellular trafﬁc, (iv) wide cellular\ncoverage, (v) reducing delay or latency, and (vi) higher spec-\ntral efﬁciency',
#  '[15]–[18].',
#  'd2d communication can be used in\nseveral ﬁelds, such as public safety, network trafﬁc ofﬂoad-\ning, military applications, social services, and gaming [19].\n',
#  'the standardization of d2d communication was reviewed\nby the third-generation partnership project (3gpp).',
#  '3gpp\nis the leading standardization organization for 5g systems,\n\nfigure 2. d2d communication and cellular network.\n\nwhich deﬁned a collection of d2d scenarios in 5gb net-\nworks [20], [21].',
#  'the latest 3gpp releases have given signif-\nicant consideration to standardize d2d communication and\ncombine it in the long-term evolution (lte) advanced ecosys-\ntem',
#  '[22].',
#  'detailed critical analysis, features, and discussion\non d2d communication standardization over 3gpp releases\nhave been presented in [23]–[26].\n\n',
#  'various survey works have made a greater contribution to\nthe research on d2d cellular networks in terms of mode selec-\ntion, resource allocation, interference management, security,\netc., which have always been to improve the d2d system per-\nformance.',
#  'however, a comprehensive survey of the current\nexisting works on the aforementioned surveys in 5g, b5g,\n\nvolume 10, 2022\n\n30793\n\n\x0cm. s. m. gismalla',
#  'et',
#  'al.: survey on d2d communication for 5gb/6g networks\n\ntion to transfer information through physical cables and con-\nnectors.',
#  'however, due to some challenges raised by multiple\nconnectors, radio frequency (rf) technology was employed\nto overcome these challenges.',
#  'thus, information was trans-\nmitted without human intervention, where rf signals trav-\neled from and to the mobile user in the transmitter’s side to\nthe base station (bs), and then bs relayed these signals to the\nother mobile user at the receiver’s side, which is standard in\nany typical cellular network as illustrated in [41]–[43].',
#  'after\nthat, due to spectrum limitations of rf technologies in the\ncellular network, d2d communications have been proposed\nto handle internet and mobile calls data trafﬁc without any\nadditional load to the core network [3], [44], which means\ndirect communication between devices would be established\nwithout relaying the signal through the bs or core of cellular\nnetwork as demonstrated in fig.2.\n\n',
#  'a direct connection between two devices (i.e., mobile,\ntablet, pc, etc.) underlaying cellular network represents\na simple concept of\nthe d2d communication mecha-\nnism,\nin which it could be classiﬁed based on spec-\ntrum utilization into in-band and out-band communication,\nas brieﬂy demonstrated with different classiﬁcation modes in\nfig.3 [19], [45].\n\n',
#  'a. in-band d2d communication\nthe motivation for selecting the in-band d2d (ibd) commu-\nnication was its high ability to control a licensed spectrum;\nhowever, it suffers from interference between d2d users and\ncellular networks [45], [46].',
#  'furthermore, it is also consid-\nered as one of the 5g technologies with spectrum efﬁciency\nthat could be improved through reusing the frequency and\ntime resources by the d2d users, in which resource sharing\nor allocation between d2d users could be performed in two\nways, namely; underlay and overlay modes [43].\n\n1) underlay mode\nin underlay mode, the d2d and cellular communications\nshare the same wireless resources, as illustrated in fig.4,\n\nfigure 3. basic classifications of d2d communications.\n\nand 6g networks is missing in the literature.',
#  'table 1 shows\na summary of comparison for the existing surveys with this\npaper.\n\n',
#  'the main contributions in this paper include:\n• an investigation of d2d communication concepts in\n5g networks, in which its classiﬁcations and various\napplications were discussed.\n\n• a review of the capability of d2d communication and\nother recent technologies integration is provided, for the\nﬁrst time, to the best of our knowledge.',
#  'these technolo-\ngies include c-ran, mm-wave, iot, vlc, udns, and\nuavs.',
#  'in addition, a discussion of the beneﬁts of their\nintegration to support 5gb networks are provided.\n\n• various d2d communication challenges and possible\nsolutions review are provided, with future research\ntrends suggestions.\n\n',
#  '• to the best of the author’s knowledge, this is the ﬁrst\nreview of d2d communications in the context of 6g\nwhich presents critical requirements for its success and\noutlines expected research directions for 6g.\n\nthe rest of this paper is organized as follows: section ii\nshows the concept and classiﬁcation of d2d communica-\ntion.',
#  'section iii presents the application of d2d communica-\ntion technology.',
#  'then, integrations between d2d and other\ntechnologies in 5gb networks are discussed in section iv.\nsection v illustrates the challenges and possible solutions\nfor further development in the future.',
#  'after that, section vi\ndescribes the d2d in 6g and critical requirements for a\nsuccessful 6g network.',
#  'the lessons learned and key ﬁnd-\nings with suggestions for future research are demonstrated\nin section vii and section viii, respectively.',
#  'lastly, conclu-\nsions are presented in section ix.\n\n',
#  'ii. d2d communication concept and\nclassification\nin the past decades, the transmission of information between\ndevices could be performed by utilizing an electrical connec-\n\n30794\n\nvolume 10, 2022\n\n\x0cm. s. m. gismalla et',
#  'al.: survey on d2d communication for 5gb/6g networks\n\ntable 1. comparison with existing d2d communication surveys.\n\nfigure 4. cellular band distribution for cellular users and d2d users in\nibd [48].\n\nfigure 5. cellular band and ism band distribution for obd',
#  '[48].\n\n',
#  'where it could improve cellular coverage, spectrum efﬁ-\nciency, and energy efﬁciency.',
#  'this is accomplished by uti-\nlizing several techniques through the network that comprises\nof resource allocation, interference mitigation, and diver-\nsity techniques',
#  '[43].',
#  'therefore, direct d2d communication\nunderlay mode could offer high spectral efﬁciency as well as\nlow latency for an end-to-end connection and physical link\nproximity, thus making it a possible solution for achieving\nthe requirements of 5g.\n\n2) overlay mode\nin overlay mode, d2d and cellular communications are given\na dedicated portion of the wireless resources so that cellular\nlinks are not inﬂuenced by d2d links [47].',
#  'nevertheless,\ninterferences between d2d links remain present.',
#  'the cellular\nband or spectrum potion of overlay is shown in fig.4.\n\nb. out-band d2d communication\n',
#  'the out-band d2d (obd) communication is another exciting\nand attractive area for many researchers today since it uses an\n\nunlicensed spectrum utilized in various industrial, scientiﬁc,\nand medical (ism) applications.',
#  'besides, it is considered\na 2.4g technology, making it difﬁcult for interference to\noccur between cellular and d2d communications, as seen in\nfig.5.',
#  'however, the obd suffers from an uncontrolled way\nof unlicensed spectrum [43], [49].',
#  'to employ the unlicensed\nspectrum band, an additional interface that performs wi-fi\ndirect, bluetooth, or zig-bee is a must.',
#  'obd communications\nare classiﬁed into two modes, based on other interface occur-\nrences, namely controlled and autonomous modes, which are\nbrieﬂy illustrated as follows:\n\n1) controlled mode\nin this mode of obd communication, the cellular network\nor base station will be controlled by radio interfaces.',
#  'in pre-\nvious studies, cellular networks have employed advanced\nmanagement techniques that can improve the reliability and\nefﬁciency of d2d communications [19], [43], and improve\n\nvolume 10, 2022\n\n30795\n\n\x0cm. s. m. gismalla et',
#  'al.: survey on d2d communication for 5gb/6g networks\n\nfuture',
#  '[57].',
#  'video streaming involves transferring data or\ncontents in a compressed form via the internet in real-time,\nwhich results in watchable content without the need to wait\nfor a completely downloaded video ﬁle',
#  '[50].',
#  'however, point-\nto-point (p2p) technology has the potential to allow all users\nto share their videos through direct communication, cellular\nnetwork, and ofﬂoading, as illustrated in fig.7 (step 4) [58].\n',
#  'it offers an alternative improved method of video streaming.\n',
#  'alternatively, d2d technology is better than conventional\ncellular networks in sharing video streaming, video con-\nferences, and video chat between devices within the same\ncellular or adjacent networks nearby.',
#  'according to future\nnetwork requirements for video streaming, the quality of\nexperience (qoe) is strongly inﬂuenced by video quality\nadaptation.',
#  'therefore, a new quality adaptation technique\nwas proposed for scalable video in d2d communication\nnetwork [13].',
#  'in addition to an extensive survey, a dis-\ncussion on video transmission and qoe was conducted in\nstudies [59], [60], which handled challenges and proposed\npossible solutions to enhance the video quality and manage\ninterferences between cellular links and d2d links.\n\nc. machine to machine\nm2m communication is considered one of the promising\ntechnologies for m2m telemetry, which involves devices\nand objects with communication and computing capabilities\nwithout the need for human connection',
#  '[50], [61], [62].',
#  'm2m\nis often utilized to monitor certain automatic transmissions\nof data collected from remote sensors to a central unit to\nbe analyzed.',
#  'this is achieved by software agents or human\nbeings, as shown in fig.8.',
#  'm2m technology has many appli-\ncations, including, but not limited to, car automation, smart\nhouses, environment monitoring, industrial automation, mili-\ntary operations, etc. furthermore, m2m machines are often\npositioned near each other in many applications to deploy\nd2d connections within a building [63], [59].',
#  'implement-\ning a direct d2d route in m2m technology will result in\nload distribution and delay reduction in deployed networks.\n',
#  'moreover, a cognitive m2m could be employed to maximize\nenergy efﬁciency [64] by utilizing a recently developed joint\noptimization algorithm that features power control, peer dis-\ncovery, channel selection, and time allocation problem.\n\n',
#  'd. emergency networks\nthe urbanization in both developing and developed worlds\nare increasing rapidly.',
#  'currently, more than 50% of the pop-\nulation is concentrated and lives in cities.',
#  'globally, this per-\ncentage is expected to grow rapidly in the upcoming decades.\n',
#  'therefore, ﬂexible and reliable communication networks in\ndense urban areas must secure global cities from unfortunate\nterror attacks, such as the new york city 9/11 catastrophe\nand 7/7 metro bombings in london',
#  '[65].',
#  'furthermore, in the\nevent of natural disasters and during search and rescue oper-\nations, base stations are often shut down or overloaded, and\ncould only provide limited services for a speciﬁc limited\nnumber of users or equipment.',
#  'hence, in emergencies, d2d-\n\nfigure 6.',
#  'd2d-5g environment scenarios and applications.\n\n',
#  'the system performance in terms of power efﬁciency and\nthroughput.',
#  'table 2 shows ibd and obd comparisons.\n\n2) autonomous mode\nalternatively, this mode does not require any changes at\ncellular networks or base stations.',
#  'it could be easily deployed,\nwhich means that autonomous d2d interfaces could be coor-\ndinated by users, resulting in cellular network',
#  'overhead mit-\nigation [19].',
#  'these autonomous d2d interfaces could be\nbluetooth or wi-fi direct.\n\nincluding video streaming,\n\niii. d2d communication applications\nd2d communication can be employed in several short\nrange applications,\n(m2m),\ndata and voice, and emergency network, as illustrated in\nfig.6.',
#  'furthermore, d2d can be used in online gaming,\nlocal advertising, cognitive-communication,\nmulticasting,\ncooperative communication, and the internet of\nthings\n(iot)',
#  '[35], [50]–[52].\n\n',
#  'a. data service and local voice\nthe transfer of data service between two devices within d2d\ncoverage areas can be achieved via d2d communication.\n',
#  'an increase in data rate and latency reduction could be\nacquired through d2d technology deployment',
#  '[50], [53].\n',
#  'additionally, voice chat services could be supported within\nnarrow proximity coverage areas such as cubicles, big halls,\nor can deliver to nearby devices.',
#  'therefore, local voice trans-\nmission through d2d technology could improve network\nperformance in terms of data rate, qos, and latency in a\nmanner that could overcome real-time voice transmission\nlimitations [54]–[56].\n\n',
#  'b. video streaming\naccording to cisco, video sharing through the internet is\nprojected to take up over 90% of internet trafﬁc in the near\n\n30796\n\nvolume 10, 2022\n\n\x0cm. s. m. gismalla et',
#  'al.: survey on d2d communication for 5gb/6g networks\n\ntable 2. comparison between in-band and out-band d2d communication.\n\nfigure 7. d2d video sharing [58].\n\nbased-technology networks could provide temporary broad-\nband services for emergency workers, doctors, and nurses to\naccess patients’ data, in addition to reporters and journalists to\ncover news and quickly disseminate government emergency\nannouncements in a timely and orderly fashion',
#  '[50], [66].\n',
#  'moreover, unmanned aerial vehicles (uav) were proposed\nas an emerging approach to deploy emergency networks\nin the case of damaged network infrastructure [67].',
#  'fig.9\nshows a large number of d2d devices that communicate with\n\neach other in a small network, in which this small network\ncan relay the data to other remote devices through a uav\ndeployed emergency network.\n\nalthough public safety, trafﬁc ofﬁcers, national secu-\nrity, and disaster management are heavily ﬂooded by d2d\ncommunications, it could be further extended to cover a wide\nrange of applications such as smart parking in smart city\nscenarios, smart grids, social networking, and smart homes,\netc. alternatively, d2d and iot technologies combination\n\nvolume 10, 2022\n\n30797\n\n\x0cm. s. m. gismalla et',
#  'al.: survey on d2d communication for 5gb/6g networks\n\nfigure 8.',
#  'm2m system model.\n\nor hybridization is an emerging approach that could poten-\ntially be utilized in intelligent internet of vehicle things\n(iovt), internet of medical things (iomt), e-medicine,\nquick disaster relief action, cloud computing, and proximity\nservices [11].',
#  'fig.10 presents a general overview of the d2d\ncommunications system with iovt, iomt, trafﬁc, and public\nsafety.\n\niv.',
#  'integration of d2d communication with\nrecent techniques\nrapid advancements, growth, and innovations in mobile com-\nmunications technologies result in a higher number of hetero-\ngeneous cellular networks.',
#  'recent advancement in cellular\nnetworks is the introduction of very-high-speed 5g technol-\nogy to the mobile market.',
#  'therefore, newly-introduced 5g\nnetworks and beyond would comprise all types of advanced\ntechnologies that offer remarkable services.',
#  'd2d underlay\ncellular network is an advanced technology that could offer\nimproved energy efﬁciency, increased capacity, and many\nother advantages due to its cellular network trafﬁc ofﬂoading\ncapabilities.',
#  'however, it faces many challenges at the same\ntime [68], [69].',
#  'to overcome all these challenges as well\nas enhance the network performance, we investigated the\nintegration and combination of d2d communication with\nother advanced technologies such as the iot, vlc, udn, etc.\n',
#  'fig.11 illustrates the most prominent technologies that can\nbe integrated with d2d communications to support 5gb net-\nworks.',
#  'a brief introduction of these technologies is presented\nin the following section.\n\na. cloud radio access network\ncloud radio access network (c-ran) is a promising access\nnetwork technique that could be employed to address\nincreased mobile trafﬁc and optimize network perfor-\nmance',
#  '[70], [71], in addition to scalability and heterogeneity\nmanagement of upcoming wireless networks.',
#  'c-ran has a\ncentralized object that aids in advanced joint mobility and\nradio resource management, which can reduce the interfer-\nence and increase data rate as well [72].',
#  'the uplink and\ndownlink scenarios for c-ran were investigated [73], [74],\nwhere different frameworks and strategies were implemented\nto improve its capacity and optimal outage probability was\nobtained.',
#  'although c-ran has many advantages, it also\nsuffers from a few drawbacks, such as link delay, one of\nits major inherent issues.',
#  'to avoid this issue, a new d2d-\ncommunication-based combination paradigm was proposed\nin [75].\n\nd2d and c-ran technologies combination does not only\nplay a signiﬁcant role in solving the delay issue, but it could\nalso fulﬁll most of 5g requirements in terms of cost, delay,\ncapacity, mobility, and energy efﬁciency [75].',
#  'both d2d\nand c-ran have been investigated to optimize resource\nallocation and mode selection simultaneously in [76], [77],\nwhich resulted in higher throughput.',
#  'd2d can be enabled\nin c-ran to improve qos as well as minimize transmitted\npower in [78].',
#  'also, c-ran-based-d2d could be employed\nto manage resource allocation for 5g heterogeneous net-\nworks [79], [80].',
#  'the performance evolution of d2d-c-ran\nbased network in 5g heterogeneous udn has yet to be\n\n30798\n\nvolume 10, 2022\n\n\x0cm. s. m. gismalla et',
#  'al.: survey on d2d communication for 5gb/6g networks\n\nfigure 9. structure of emergency networks in disaster using d2d and uav technologies.\n\ninvestigated.',
#  'more studies are required to ascertain its ful-\nﬁllment of the 5g requirements.',
#  'moreover, new algorithms\nfor delay reduction in hybrid d2d-c-ran network is needed\nto improve the performance in terms of interference, optimal\noutage probability, throughput, qos, etc.\n\nb. millimeter-wave\nthe electromagnetic spectrum is becoming more and more\ncongested; as a result, its resources have become sparse due to\nthe massive applications demand, which occupies most of its\nremaining frequency bands.',
#  'therefore, moving to millimeter-\nwave (mm-wave) bands has become a necessity for the large\nunused bandwidths [81], [82].',
#  'the mm-wave spectrum is\ndescribed by an extremely high-frequency band (ehf) and\nranges from 30 to 300 ghz.',
#  'these bands could support 5g\nnetworks with a possibility of obtaining 1000 folds the capac-\nity compared to 4g solutions [76], [81].',
#  'employing d2d\ncommunication in micro-wave bands suffers from high inter-\nference and insufﬁcient bandwidth [83].',
#  'therefore, enabling\nd2d in an mm-wave band is another possible solution to\nthose problems.\n\n',
#  'mm-wave provides low latency and high data rate; how-\never, it suffers from inefﬁcient power consumption and prop-\nagation shortcomings [84].',
#  'to overcome these challenges,\npower consumption could be improved by d2d communi-\ncation integration with mm-wave technology as introduced\nin [85], which resulted in improved energy efﬁciency.',
#  'this\nintegration provided high data rates, low interference as\nwell as improved power consumption [86].',
#  'in addition, the\noutage probability and data rates were investigated for a\ncombination of both and based on various mm-wave parame-\nters',
#  '[86].',
#  'a new optimization problem formula has also been\nimplemented to investigate resource and power allocation of\nd2d and mm-wave integration in [87].',
#  'besides, an exten-\nsive survey about integrating both technologies has been\ndone, which covered cooperative communication, caching,\nscheduling techniques, beamforming, and their possible solu-\ntion approaches [88], [89].\n\n',
#  'moreover, both technologies suffer challenges such as\nblockage modeling, heterogeneous networks, and densiﬁ-\ncation.',
#  'despite all mentioned challenges, there are great\nchances for integrated d2d communication with mm-wave\nto become a promising solution form many issues relating to\n\nvolume 10, 2022\n\n',
#  '30799\n\n\x0cm. s. m. gismalla et',
#  'al.: survey on d2d communication for 5gb/6g networks\n\nfigure 10.',
#  'general applications for d2d communication system [51].\n\nsimilar to the method that humans utilize in the internet,\ndevices are the major users in the iot ecosystem [90].',
#  'the\nfast growth of smartphones plays a signiﬁcant role in sup-\nporting iot technology and it has gained a strong interest\nby many due to its features that can support the creation\nand the development of various services and applications.\n',
#  'moreover, d2d and iot technologies integration have the\npotential to satisfy upcoming 5g requirements, especially\nin terms of system capacity, latency, or delay, as well as\nspectral efﬁciency [51], [91].',
#  'two interference management\ntechniques termed as cooperative pairing (coop) and ﬁxed\npower margin (fpm) have been investigated to improve the\noutage probability and qos requirement for the combined\nd2d and iot ecosystem',
#  '[92].',
#  'the role of d2d communica-\ntion in the development of the iot ecosystem was extensively\ndiscussed, where the past, current status, and expected future\nissues were also presented [93].',
#  'fig.12 shows the integrated\nd2d communication with 5g iot networks [94].\n\n',
#  'd. visible light communication\nrf technology suffers from capacity crunch, interference,\nand other constraints, that affect the performance of the com-\nmunication system.',
#  'in order to avoid some of these con-\nstraints, a new technology named vlc was introduced [95]–\n[97].',
#  'vlc features a high bandwidth that could reach up\nto terahertz (thz), in addition to low power, license-free\ndeployment, and interference immunity [98], [99].',
#  'table\n3 provides a comparison between vlc and rf technolo-\ngies',
#  '[100], [101].',
#  'similar to d2d communications, vlc\nsystem has limited coverage distance.',
#  'therefore, both tech-\nnologies would be suitable for indoor applications; such sce-\nnarios can produce high capacity and high data rates.\n\nfigure 11. integration of d2d communication with different recent\ntechnologies in 5g.\n\n5g and beyond.',
#  'the integration of both technologies opens\nareas for researchers in the academia and industry to realize\nand investigate d2d communication integration in the mm-\nwave spectrum band.\n\n',
#  'c. internet of things\ninternet of things (iot) is an emerging technology used to\ncreate an integrated ecosystem for various devices to com-\nmunicate with each other via the internet [2].',
#  'therefore,\n\n30800\n\nvolume 10, 2022\n\n\x0cm. s. m. gismalla et',
#  'al.: survey on d2d communication for 5gb/6g networks\n\ntable 3.',
#  'rf versus vlc technologies',
#  '[100], [101].\n\n',
#  'figure 12.',
#  'integrated d2d communications with 5g iot networks.\n\n',
#  'the hierarchical game method was utilized to investi-\ngate resource allocation for a hybrid d2d and vlc in\nheterogeneous networks [96].',
#  'it was shown that hybrid\nrf-vlc in d2d communication network achieved improved\nperformance in terms of capacity crunch in indoor environ-\nments',
#  '[102].',
#  'furthermore, an rf-vlc d2d system maxi-\nmized the capacity of rf d2d communication and vlc d2d\ncommunication systems with rates of 4.1 and 1.5, respec-\ntively [103].',
#  'fig.13 illustrates a hybrid vlc-rf link in a d2d\ncommunication system, where device user equipment (due)\nrepresents the device user equipment, t and r denote the\ntransmitter and receiver, respectively.\n\n',
#  'the mobility management of combined d2d communi-\ncation with hybrid rf/vlc bands has been investigated\nin [104], [105].',
#  'the combination of all these technolo-\ngies could improve system capacity and overcome the over-\ncrowded rf bands [10].',
#  'therefore, new algorithms were\ndeveloped for d2d communication to switch from rf to\nvlc and vice versa based on average energy efﬁciency, sum\ncapacity, and outage ratio.\n\nfigure 13.',
#  'hybrid vlc- rf in d2d communication system.\n\n',
#  'e. ultra-dense network\ncurrently, researchers are discussing and investigating the\npotential of combining ultra-dense networks (udns) with\n\nvarious technologies in order to fulﬁll the extraordinary\ncapacity requirement of 5g [106], [107].',
#  'the distribution\nof ultra-dense small cells instead of conventional macrocells\n\nvolume 10, 2022\n\n30801\n\n\x0cin the coverage area is known as udn.',
#  'however, udn\nintroduces new challenges that need to be solved, such as\ninterference, degraded qos, and high energy consumption.\nto overcome these challenges, udn should be integrated\nwith other technologies such as d2d communication.',
#  'fig.14\nshows a simple combination of udn and d2d communica-\ntion, in which different cell sizes such as macrocell, femto-\ncell, and picocell are distributed to enhance the rising number\nof devices or user equipment (ue)',
#  '[108].',
#  'moreover, the ue\nor devices located at cell edge that lacks connectivity, due to\ncoverage limitations, require a relayer for incorporation and\nconnection with the d2d communication cell.\n\nalthough udn has interference challenges, qos, and\nother constraints, it could improve the performance of the net-\nwork and increase its capacity 100-fold [109].',
#  'furthermore,\nd2d communication integration is a signiﬁcant factor in sav-\ning energy consumption due to the massive cell distribution\nwithin udn',
#  '[108].',
#  'besides, it can provide support for other\nsolutions that could overcome the challenges to satisfy the\nrequirements of 5g and beyond.\n\nf. unmanned aerial vehicle\nin remote, disaster-affected, and rural areas, it is often dif-\nﬁcult to build wireless networks due to challenging terrain\nor lack of infrastructure.',
#  'however, unmanned aerial vehicles\n(uavs) could be immediately deployed to establish a d2d\nauthorized wireless network with high qos, which make\nthem a promising technology for emergency scenarios',
#  '[110]–\n[112].',
#  'alternatively, d2d communication plays a signiﬁcant\nrole in improving the performance of uav in terms of capac-\nity and coverage expansion with proper communication in\nwireless cellular networks [113].\n\n',
#  'potential challenges of integrating uavs and d2d com-\nmunication networks were investigated in [54], in which the\nemployment of dynamic multi uavs was explored.',
#  'more-\nover, a 3d resource sharing between d2d and uavs was\ninvestigated to improve the spectral efﬁciency of cellular\nnetworks in [114].',
#  'besides, in [115], the authors proposed\nand evaluated the performance of a couple of mode selec-\ntion schemes for d2d-enabled uav-based wireless networks,\nwhere they utilized received signal strength threshold and\naverage distance threshold to improve signal quality and\nconnectivity in the case of emergencies.',
#  'furthermore, d2d\ncommunication and caching technologies were employed to\nmitigate uav-assisted cellular network trafﬁc [116].',
#  'besides\nthat, trajectory optimization and analysis of cache-enabled\nuav-assisted cellular networks based on d2d communica-\ntion underlay were discussed, in which the dynamic and static\nuav deployments were considered.',
#  'although both uav and\nd2d technologies have various advantages and could be\npromising candidates for 5gb network fulﬁllment, their high\nmobility and dynamic topology, when combined, could hin-\nder the performance of allocation algorithm in a conventional\nchannel, in addition to interference, energy consumption,\nand a limited number of available orthogonal channels for\nresource allocation.',
#  'the development of new algorithms and\n\nm. s. m. gismalla et al.: survey on d2d communication for 5gb/6g networks\n\noptimization solutions for these issues have yet to be resolved\nand remain an attractive problem to be researched in the\nfuture, along with the potential use of uav as a portable\nenergy source, due to its ﬂexibility.\n\nv. challenges and possible solutions for d2d\ncommunication in 5gb networks\nas discussed previously, d2d communication presents a\nnovel paradigm and standard that could be incorporated\nin contemporary mobile cellular networks,\nin which it\ncan facilitate improved data exchange between proximate\ndevices.',
#  'network performance improvements are continu-\nously needed.',
#  'therefore, mobile operators are consistently\ndeveloping technologies that support close-proximity ser-\nvices by advancing d2d communications technologies [28].\n',
#  'the taxonomy challenges for the d2d communication\ntechnique in 5gb are as demonstrated in fig.',
#  '15.',
#  'it includes\nthe different parameters which categorize the available lit-\nerature in d2d communication networks.',
#  'the taxonomy\nincludes six divisions, each of which displays various param-\neters, their sub-divisions, and the related literature.',
#  'the\nparameters on which the category is done are resource allo-\ncation of the radio spectrum, interference management, com-\npatibility between devices in heterogeneous networks, mode\nselection, security, and mobility.\n\n',
#  'resource allocation for d2d communication in 5gb is\neither underlay or overlay, and both are categorized as central-\nized, distributed, and semi-distributed.',
#  'it is also managed by\nvarious algorithms and optimization problems [117]–[119].\n',
#  'interference is classiﬁed into interference cancellation, inter-\nference coordination, and interference avoidance [26], [120].\n',
#  'furthermore, interference cancellation is divided into three\ntypes known as sic, pic, and iic.',
#  'various mechanisms are\nemployed for interference avoidance, which includes mode\nselection, joint power control, transmit power control, joint\nresource allocation, and mimo techniques.\n\n',
#  'heterogeneous network is categorized into access mode,\ncell type, and network model based on the past works [121]–\n[123], and each category involves sub-branches.',
#  'mode selec-\ntion in d2d communication is classiﬁed based on trans-\nmission modes and control.',
#  'both of them are divided into\nsub-division as discussed in [124], [125].\n',
#  'security is categorized into requirements, threats, and solu-\ntions.',
#  'the requirements are discussed, which contain c\\i, au,\nfac, pr, re, a\\d, and nr [126], [127].',
#  'besides that, vul-\nnerability classiﬁcations include physical attacks, negotiated\nids, conﬁguration attacks, protocol attacks, attacks on core\nnetworks, and user data and privacy attacks [28], [126], [128].\n',
#  'four types of security solutions are classiﬁed, namely secure\nrouting, access control, physical layer security, and authen-\ntication, and key management [126].',
#  'the mobility manage-\nment contains joint handover, half handover, and sidelink-\nassisted handover',
#  '[27], [104], [129].',
#  'all these challenges and\npossible solutions for d2d communications in the context\nof 5g networks and beyond are discussed in the following\nsubsections.',
#  'also, some notable methods with the ability\n\n30802\n\nvolume 10, 2022\n\n\x0cm. s. m. gismalla et',
#  'al.: survey on d2d communication for 5gb/6g networks\n\nfigure 14.',
#  'general example of udn',
#  '[108].\n\nto solve d2d communication challenges were investigated,\nalong with in-depth technical discussion that includes objec-\ntives, contributions, mechanisms, and results (see table 4).',
#  '\n\na. resource allocation\nradio resource allocation is an essential element in maintain-\ning and creating direct connections between d2d pairs under\ncellular networks [32], [130].',
#  'the advantages of d2d radio\nresource allocations are ﬂexibility, ubiquitous availability,\nlow latency, and',
#  'low cost',
#  '[51].',
#  'spectrum sharing between\nd2d users and cellular user equipment (cue), mainly within\nin-band mode, can improve spectral and energy efﬁciency by\nmanaging co-channel interference [30], [131], [132].',
#  'another\nnovel technique is sparse code multiple access (scma),\nwhich was utilized in d2d communications for 5g networks\nparadigm to improve resource and power utilization in hybrid\ncellular networks [133].',
#  'however, security issues and fair-\nness of communication have yet to be explored.',
#  'meanwhile,\nvarious resource allocation methods with different perfor-\nmance objectives were investigated in [51], [134]–[136].',
#  'for\nfuture directions, effective resource allocation techniques are\nneeded to satisfy the requirements of 5g and beyond to\nachieve minimized signaling overload in the cellular network\n(base station), obtain acceptable user data rates, maximize\nnetwork throughput, and meet qos demands.\n\n',
#  'b. interference management\ninterference from cellular users (cus) is one of the primary\nimpairments inﬂuencing d2d communication.',
#  'reuse of cel-\nlular network resources and, therefore, the coexistence of\n\ncus and d2d pairs will lead to elevated interference prob-\nlems.',
#  'd2d user experience often suffers from two types of\ninterference; intracell and intercell interference.',
#  'both depend\non operation modes of the d2d network and could occur\nin uplink or downlink scenarios [31].',
#  'they can obstruct\nsuccessful transmissions through signal to noise ratio (snr)\nreduction at the receiver end and result in decreased qos\nas well.',
#  'transmitted power as a reduction technique is usu-\nally implemented to mitigate the effect of ues interferences.\n',
#  'however, it results in a qos tradeoff at the receiver end.\n\n',
#  'various interference management techniques have been\ndiscussed and proposed in previous studies, including inter-\nference coordination,\ninterference avoidance, and inter-\nference cancellation.',
#  'moreover, transmissions scheduling,\nhybrid automatic repeat request (harr), coding, and modu-\nlation techniques are also implemented to improve the robust-\nness of the signal against noise and mitigate unwanted inter-\nference [32].',
#  'research in the approaches mentioned above\nremains active.\n\n',
#  'the future direction of interference management of d2d\nin 5g networks concentrates on the power control and inter-\nference mitigation techniques, and both can lead to improved\nenergy utilization, which is one of the essential aims of the\nfuture generation of wireless networks.\n\n',
#  'c. compatibility between devices in\nheterogeneous network\n5g communication focuses on iot and d2d technolo-\ngies for various applications such as connected smart\ncars, active monitoring, smart houses, connected e-health,\n\nvolume 10, 2022\n\n30803\n\n\x0ctable 4. technical analysis and solutions for d2d communication challenges.\n\n',
#  'm. s. m. gismalla et',
#  'al.: survey on d2d communication for 5gb/6g networks\n\n30804\n\nvolume 10, 2022\n\n\x0cm. s. m. gismalla et al.: survey on d2d communication for 5gb/6g networks\n\ntable 4. (continued.)',
#  'technical analysis and solutions for d2d communication challenges.\n\nvolume 10, 2022\n\n30805\n\n\x0ctable 4. (continued.)',
#  'technical analysis and solutions for d2d communication challenges.\n\n',
#  'm. s. m. gismalla et',
#  'al.: survey on d2d communication for 5gb/6g networks\n\n30806\n\nvolume 10, 2022\n\n\x0cm. s. m. gismalla et al.: survey on d2d communication for 5gb/6g networks\n\ntable 4. (continued.)',
#  'technical analysis and solutions for d2d communication challenges.\n\nvolume 10, 2022\n\n30807\n\n\x0ctable 4. (continued.)',
#  'technical analysis and solutions for d2d communication challenges.\n\n',
#  'm. s. m. gismalla et',
#  'al.: survey on d2d communication for 5gb/6g networks\n\nin order\n\nsmart wearables, etc. hence,\nto establish an\nefﬁcient connection and acquire compatibility among all\nthese different devices, a d2d heterogeneous network is\nneeded to support multiple communication systems diver-\nsity',
#  '[121],\n[122].',
#  'a new design of a heterogeneous\nwireless network between bluetooth low energy (ble)\nand wi-fi with a high data rate (halow) was studied\nin [160], which was achieved through a vertical han-\ndover scenario.',
#  'both ble and halow technologies work\non different frequency bands, and the coexistence of both\ndiverse networks does not require an interference avoidance\nmechanism.\n\n',
#  'future research will be focused on establishing a fully reli-\nable communication link between different devices in diverse\nnetworks, which requires new transportation and translation\nprotocols to develop a uniﬁed compatible global system,\nin which data sharing between various d2d users in the iot\necosystem in udn is facilitated.',
#  '\n\n',
#  'd. mode selection\nmode selection (ms) is a critical\nissue in d2d com-\nmunication and is an efﬁcient method that\nimproves\nenergy efﬁciency, network throughput, and reduces interfer-\nence',
#  '[161], [162].',
#  'it determines whether d2d users could\noperate under a direct mode or cellular mode, and it could\nselect static or dynamic time scale',
#  '[163].',
#  'the selection of\ncommunication mode for dues is a ﬂexible process when\ndues select the d2d mode; the latency can be reduced, and a\nhigher spectrum resource utilization could be achieved [161].\n',
#  'different dues model selection and algorithms have been\ninvestigated for d2d heterogeneous networks for various\naims [125], [161], [164].',
#  'three d2d communication modes\ncan be allocated by the base station (bs) to every d2d pair,\nwhich comprises of direct d2d, local route, and relay d2d.\n',
#  'a new optimal ms algorithm was proposed to maximize the\ncapacity and cellular coverage in [165].',
#  'also, the effect of\nms on the adequate capacity of d2d communication has\n\n30808\n\nvolume 10, 2022\n\n\x0cm. s. m. gismalla et',
#  'al.: survey on d2d communication for 5gb/6g networks\n\nbeen investigated in [166].',
#  'the development of optimal ms\nalgorithms is an area of interest for future research directions,\nwhich not only could obtain maximum capacity, but also\nimprove spectral efﬁciency and reduce system interference.\n\n',
#  'e. security\nnowadays, d2d communication network security has\nattracted attention due to the nature of data distribution across\ncommunication networks.',
#  'd2d pairs can distribute sensitive\ninformation and data related to identifying the users and addi-\ntional personal details',
#  '[31], [126].',
#  'this information should\nbe secure and safe to prevent any impersoniﬁcation, eaves-\ndropping, ip spooﬁng, denial of service, and malware attack\nby hackers for illegal purposes [32].',
#  'accordingly, network\nsecurity protocols were developed in d2d networks, which\nenable users to avoid information leakages.\n\ndynamic readjustment of d2d users due to mobility is a\nsigniﬁcant issue in establishing secure d2d communication\nnetworks.',
#  'new and old d2d users may join and leave the\ncoalition, which requires an adaptive mechanism for d2d\ncommunication security [126].',
#  'moreover, a novel technique\nthat utilizes interference signals as an impediment for security\nwas introduced in [167], [168].',
#  'this was done by obstruct-\ning the eavesdropping device.',
#  'different security models and\nalgorithms were designed to measure the security workload\non heterogeneous mobile devices',
#  '[169]–[171].',
#  'besides that,\nan in-depth survey on security design aims was introduced\nin [126], [157], [172].',
#  'the survey included authentication,\nsecure routing, key management, physical layer, access con-\ntrol, and additional security issues.',
#  'however, many security\nproblems remain to be discussed, which may open up many\nresearch directions in the future, and great efforts must be met\nto ensure d2d security.\n\nf.',
#  'mobility\nthe users are mobile in cellular networks, and communi-\ncations are automatically activated and dropped based on\nthe d2d user’s relative position.',
#  'however, most research\nrelated to d2d communication concentrated on static\nusers [173], [174].',
#  'smart mobility solutions were proposed to\nmitigate the network overhead due to signaling and enhance\nthe d2d end-to-end (e2e) latency through maximizing the\ntime when the due is controlled by the small cell itself [153].\n',
#  'more investigation is required to explain how d2d perfor-\nmance increases in dynamic scenarios, and what handover\nand interference in the treating mechanism are needed as d2d\nusers move across and within cells.',
#  'also, the relay or multi-\nhop d2d communication poses many challenges.\n\n',
#  'vi. future of d2d communication in 6g network\nthe sixth-generation (6g) of mobile communication is\nexpected to launch commercially in 2030, which will allow\nthe internet of everything (ioe).',
#  'this will revolutionize the\nlifestyle, intelligent mobile society, personal life, and com-\nmunication and business systems.',
#  '5g and beyond will per-\nhaps not be able to attain all ioe requirements [175]–[178],\n\nand this will push researchers towards looking for solutions\nthat can meet higher demands in 6g. many researchers in\nacademia and industrial ﬁelds have already started vision-\ning, planning, and aggregating requirements of 6g technolo-\ngies.',
#  'also, many countries, such as china and finland, have\nalready begun research on 6g topics.',
#  'table 5 shows a com-\nparison between 5g and the possible capabilities of future 6g.\nthe challenges and problems of 6g are mainly focused\non energy and spectrum efﬁciency, capacity, and system\ncoverage, besides movement speed and user data rate',
#  '[181].\n',
#  'therefore, to solve these challenges, some key technologies\nand novel approaches for 6g and beyond were presented,\nas shown in fig.16',
#  '[176], including network slicing (ns),\ncognitive network (cn), mobile edge computing (mec),\nterahertz communication (thz).',
#  'in addition to other tech-\nnologies such as non-orthogonal multiple access (noma),\nintelligent reﬂecting surfaces (irs), etc.',
#  '[182].\n\n',
# ...
#  'conf.',
#  'comput., commun.,\nmillimeter wave bands,’’\nchem., mater.',
#  'electron.',
#  'eng.',
#  '(ic4me2), jul.',
#  '2019, pp.',
#  '1–4, doi:\n10.1109/ic4me247184.2019.9036505.\n\ndevice-to-device\n\ncommunications\n\nfor\n\nin proc.\n\n',
#  '[84] c. zhang, w. zhang, w. wang, l. yang, and w. zhang, ‘‘research\nchallenges and opportunities of uav millimeter-wave communications,’’\nieee wireless commun., vol.',
#  '26, no. 1,',
#  'pp.',
#  '58–62, feb. 2019, doi:\n10.1109/mwc.2018.1800214.\n\n',
#  '[85] n. zabetian, a. mohammadi, and m. kazemi, ‘‘energy efﬁciency opti-\nmization for device-to-device communication underlaying cellular net-\nworks in millimeter-wave,’’ int.',
#  'j. commun.',
#  'syst., vol.',
#  '33, no. 6, p. e4287,\napr.',
#  '2020, doi: 10.1002/dac.4287.\n\n',
#  '[86] r. d. govenker, a. y. phatak, r. bajpai, and n. gupta, ‘‘outage\nanalysis of mmwave integrated device-to-device communication system\nunder nakagami fading channel,’’ in proc.',
#  'nat.',
#  'conf. commun.',
#  '(ncc),\nfeb. 2020, pp.',
#  '1–6, doi: 10.1109/ncc48643.2020.9056087.\n\n',
#  '[87] s. g. hong, j. park, and s. bahk, ‘‘subchannel and power alloca-\ntion for d2d communication in mmwave cellular networks,’’ j. com-\nmun.',
#  'netw., vol.',
#  '22, no. 2, pp.',
#  '118–129, apr.',
#  '2020, doi: 10.1109/jcn.\n2020.000007.\n\n',
#  '[88] o. yazdani, g. mirjalily, and m. monemi, ‘‘efﬁcient transmit antenna\nselection and resource allocation scheme for mmwave d2d networks,’’\naeu-int.',
#  'j. electron.',
#  'commun., vol.',
#  '123, aug. 2020, art.',
#  'no.',
#  '153271,\ndoi: 10.1016/j.aeue.2020.153271.\n\n',
#  '[89] f. o. ombongi, a. ouma, and p. kibet, ‘‘performance analysis for\nmillimeter wave device-to-device communication networks: a review,’’\nin proc.',
#  'sustain.',
#  'res.',
#  'innov.',
#  'conf., 2020, pp.',
#  '132–141.\n\n',
#  '[90] o. bello, s. zeadally, and m. badra, ‘‘network layer inter-operation\nof device-to-device communication technologies in internet of things\n(iot),’’ ad hoc netw.',
#  'j., vol. 57, pp.',
#  '52–62, mar. 2017, doi:\n10.1016/j.adhoc.2016.06.010.\n\n',
#  '[91] m. a. kandi, h. lakhlef, a. bouabdallah, and y. challal, ‘‘a versatile\nkey management protocol for secure group and device-to-device com-\nmunication in the internet of things,’’ j. netw.',
#  'comput.',
#  'appl., vol.',
#  '150,\njan. 2020, art.',
#  'no. 102480, doi: 10.1016/j.jnca.2019.102480.\n\n30816\n\nvolume 10, 2022\n\n\x0cm. s. m. gismalla et',
#  'al.: survey on d2d communication for 5gb/6g networks\n\n[92] b. m. elhalawany, r. ruby, and k. wu, ‘‘d2d communication\nfor enabling internet-of-things: outage probability analysis,’’ ieee\ntrans.',
#  'veh. technol., vol.',
#  '68, no. 3, pp.',
#  '2332–2345, mar.',
#  '2019, doi:\n10.1109/tvt.2019.2891648.\n\n',
#  '[93] p. pawar and a. trivedi, ‘‘device-to-device communication based iot\nsystem: beneﬁts and challenges,’’ iete tech.',
#  'rev., vol. 36, no. 4,\npp.',
#  '362–374, jul.',
#  '2019, doi: 10.1080/02564602.2018.1476191.\n\n',
#  '[94] l. militano, g. araniti, m. condoluci, i. farris, and a. iera, ‘‘device-\nto-device communications for 5g internet of things,’’ eai endorsed\ntrans.',
#  'internet things, vol.',
#  '1, no. 1, oct. 2015, art.',
#  'no. 150598, doi:\n10.4108/eai.26-10-2015.150598.\n\n',
#  '[95] m. s. m. gismalla, m. f. l. abdullah, b. das, w. a. mabrouk, and\nn. e. mahfouz, ‘‘design of an optical attocells conﬁguration for an indoor\nvisible light communications system,’’ aeu-int.',
#  'j. electron.',
#  'commun.,\nvol.',
#  '112, dec. 2019, art.',
#  'no. 152946, doi: 10.1016/j.aeue.2019.152946.\n',
#  '[96] h. zhang, w. ding, f. yang, j. song, and z. han, ‘‘resource allocation\nin heterogeneous network with visible light communication and d2d:\na hierarchical game approach,’’ ieee trans.',
#  'commun., vol.',
#  '67, no. 11,\npp.',
#  '7616–7628, nov. 2019, doi: 10.1109/tcomm.2019.2936849.\n\n',
#  '[97] m. s. m. gismalla, m. f. l. abdullah, m. s. ahmed, w. a. mabrouk,\nand a.-f.',
#  'najib, ‘‘design and analysis of different optical attocells\ndeployment models for indoor visible light communication system,’’ int.\nj. integr.',
#  'eng., vol. 13, no. 6, pp.',
#  '253–264, 2021.\n\n',
#  '[98] m. s. m. gismalla, m. f. l. abdullah, m. i. niass, b. das, and\nw. a. mabrouk, ‘‘improve uniformity for an indoor visible light com-\nmunication system,’’ int.',
#  'j. commun.',
#  'syst., vol.',
#  '33, no. 8, p. e4349,\nmay 2020, doi: 10.1002/dac.4349.\n\n',
#  '[99] m. s. m. gismalla and m. f. l. abdullah, ‘‘optimization of received\npower and snr for an indoor attocells network in visible light\ncommunication,’’ j. commun., vol.',
#  '14, no. 1, pp.',
#  '64–69, 2019, doi:\n10.12720/jcm.14.1.64-69.\n\n',
#  '[100] h. burchardt, n. seraﬁmovski, d. tsonev, s. videv, and h. haas, ‘‘vlc:\nbeyond point-to-point communication,’’ ieee commun.',
#  'mag., vol.',
#  '52,\nno. 7, pp.',
#  '98–105, jul. 2014, doi: 10.1109/mcom.2014.6852089.\n\n',
#  '[101] d. tsonev, s. videv, and h. haas, ‘‘light ﬁdelity (li-fi): towards all-\noptical networking,’’ proc.',
#  'spie, vol. 9007, feb. 2014, art.',
#  'no. 900702.\n',
#  '[102] z. becvar, m. najla, and p. mach, ‘‘selection between radio frequency\nand visible light communication bands for d2d,’’ in proc.',
#  'ieee 87th\nveh. technol.',
#  'conf.',
#  '(vtc spring), jun.',
#  '2018, pp.',
#  '1–7, doi: 10.1109/vtc-\nspring.2018.8417703.\n\n',
#  '[103] p. mach, z. becvar, m. najla, and s. zvanovec, ‘‘combination of\nvisible light and radio frequency bands for device-to-device commu-\nnication,’’ in proc.',
#  'ieee 28th annu.',
#  'int.',
#  'symp.',
#  'pers., indoor, mobile\nradio commun.',
#  '(pimrc), oct. 2017, pp.',
#  '1–7, doi: 10.1109/pimrc.\n',
#  '2017.8292746.\n\n',
#  '[104] z. becvar, r.-g.',
#  'cheng, m. charvat, and p. mach,\n\n‘‘mobility\nfor d2d communication combining radio frequency\nmanagement\nbands,’’ wireless netw.,\nand\nvisible\nvol. 26, no. 7, pp.',
#  '5473–5484, oct. 2020, doi: 10.1007/s11276-\n020-02408-x.\n\ncommunications\n\nlight\n\n[',
#  '105] m. najla, p. mach, z. becvar, p. chvojka, and s. zvanovec, ‘‘efﬁcient\nexploitation of radio frequency and visible light communication bands\nfor d2d in mobile networks,’’ ieee access, vol.',
#  '7, pp.',
#  '168922–168933,\n2019, doi: 10.1109/access.2019.2954049.\n\n',
#  '[106] m. a. adedoyin and o. e. falowo, ‘‘combination of ultra-dense networks\nand other 5g enabling technologies: a survey,’’ ieee access, vol. 8,\npp.',
#  '22893–22932, 2020, doi: 10.1109/access.2020.2969980.\n\n',
#  '[107] o. alamu, a. gbenga-ilori, m. adelabu, a. imoize, and o. ladipo,\n‘‘energy efﬁciency techniques in ultra-dense wireless heterogeneous net-\nworks: an overview and outlook,’’ eng.',
#  'sci. technol., int.',
#  'j., vol.',
#  '23,\nno. 6, pp.',
#  '1308–1326, dec. 2020, doi: 10.1016/j.jestch.2020.05.001.\n\n',
#  '[108] m. f. hashim and n. i. a. razak, ‘‘ultra-dense networks: integration\nwith device to device (d2d) communication,’’ wireless pers.',
#  'com-\nmun., vol. 106, no. 2, pp.',
#  '911–925, may 2019, doi: 10.1007/s11277-\n019-06195-3.\n\n',
#  '[109] i. hwang, b. song, and s. s. soliman, ‘‘a holistic view on hyper-dense\nheterogeneous and small cell networks,’’ ieee commun.',
#  'mag., vol.',
#  '51,\nno. 6, pp.',
#  '20–27, jun.',
#  '2013, doi: 10.1109/mcom.2013.6525591.\n\n',
#  '[110] f. tang, z. m. fadlullah, n. kato, f. ono, and r. miura, ‘‘ac-\npoca: anticoordination game based partially overlapping channels\nieee\nassignment\ntrans.',
#  'veh. technol., vol.',
#  '67, no. 2, pp.',
#  '1672–1683, feb. 2018, doi:\n10.1109/tvt.2017.2753280.\n\nin combined uav and d2d-based networks,’’\n\n[111] b. shang, l. liu, j. ma, and p. fan, ‘‘unmanned aerial vehicle\nieee\nmeets\ncommun.',
#  'mag., vol.',
#  '57, no. 10, pp.',
#  '98–103, oct. 2019, doi:\n10.1109/mcom.001.1900170.\n\nvehicle-to-everything\n\ncommunications,’’\n\nin\n\nsecure\n\n[112] a. i. hentati and l. c. fourati, ‘‘comprehensive survey of uavs com-\nmunication networks,’’ comput.',
#  'standards inter., vol.',
#  '72, oct. 2020,\nart.',
#  'no. 103451, doi: 10.1016/j.csi.2020.103451.\n\n',
#  '[113] a. trivedi and p. pawar, ‘‘d2d in uav networks,’’ in wiley 5g ref essent.\n\n',
#  '5g ref.',
#  'online.',
#  '2019, pp.',
#  '1–17.\n\n',
#  '[114] b. shang, l. liu, r. m. rao, v. marojevic, and j. h. reed,\n‘‘3d spectrum sharing for hybrid d2d and uav networks,’’ ieee\ntrans. commun., vol. 68, no. 9, pp. 5375–5389, sep.',
#  '2020, doi:\n10.1109/tcomm.2020.2997957.\n\n',
#  '[115] a. omri, m. o. hasna, m. z. shakir, and m. shaqfeh, ‘‘mode selection\nschemes for d2d enabled unmanned aerial vehicle-based wireless net-\nworks,’’ iet commun., vol.',
#  '13, no. 10, pp.',
#  '1397–1404, jun.',
#  '2019, doi:\n10.1049/iet-com.2018.5834.\n\n',
#  '[116] j. ji, k. zhu, d. niyato, and r. wang, ‘‘probabilistic cache placement\nin uav-assisted networks with d2d connections: performance analysis\nand trajectory optimization,’’ ieee trans. commun., vol.',
#  '68, no. 10,\npp.',
#  '6331–6345, oct. 2020, doi: 10.1109/tcomm.2020.3006908.\n\n',
#  '[117] i. budhiraja, n. kumar, and s. tyagi, ‘‘deep-reinforcement-learning-\nbased proportional fair scheduling control scheme for underlay d2d\ncommunication,’’ ieee internet things j., vol. 8, no. 5, pp.',
#  '3143–3156,\nmar.',
#  '2021, doi: 10.1109/jiot.2020.3014926.\n\n',
#  '[118] a. sultana, l. zhao, and x. fernando, ‘‘efﬁcient resource allocation\nin device-to-device communication using cognitive radio technology,’’\nieee trans.',
#  'veh. technol., vol.',
#  '66, no. 11, pp.',
#  '10024–10034, nov. 2017,\ndoi: 10.1109/tvt.2017.2743058.\n\n',
#  '[119] a. sultana, l. zhao, and x. fernando, ‘‘energy-efﬁcient power allocation\nin underlay and overlay cognitive device-to-device communications,’’\niet commun., vol. 13, no. 2, pp.',
#  '162–170, jan. 2019, doi: 10.1049/iet-\ncom.2018.5464.\n\n',
#  '[120] m. noura and r. nordin, ‘‘a survey on interference management for\ndevice-to-device (d2d) communication and its challenges in 5g net-\nworks,’’ j. netw.',
#  'comput.',
#  'appl., vol.',
#  '71, pp.',
#  '130–150, aug. 2016, doi:\n10.1016/j.jnca.2016.04.021.\n\n',
#  '[121] x. zhang, w. gu, h. zhang, and m. wang,\n\n‘‘hybrid commu-\nnication path orchestration for 5g heterogeneous ultra-dense net-\nworks,’’ ieee netw., vol.',
#  '33, no. 4, pp.',
#  '112–118, jul.',
#  '2019, doi:\n10.1109/mnet.2019.1800402.\n\n',
#  '[122] k. xu, y. qu, and k. yang, ‘‘a tutorial on the internet of things:\nfrom a heterogeneous network integration perspective,’’ ieee net-\nwork, vol.',
#  '30, no. 2, pp.',
#  '102–108, mar.',
#  '2016, doi: 10.1109/mnet.\n',
#  '2016.7437031.\n\n',
#  '[123] y. xu, g. gui, h. gacanin, and f. adachi, ‘‘a survey on resource alloca-\ntion for 5g heterogeneous networks: current research, future trends, and\nchallenges,’’ ieee commun.',
#  'surveys tuts., vol.',
#  '23, no. 2, pp.',
#  '668–695,\n2nd quart., 2021, doi: 10.1109/comst.2021.3059896.\n\n',
#  '[124] i. ioannou, c. christophorou, v. vassiliou, and a. pitsillides, ‘‘perfor-\nmance evaluation of transmission mode selection in d2d communica-\ntion,’’ in proc.',
#  '11th ifip int.',
#  'conf.',
#  'new technol., mobility secur.',
#  '(ntms),\napr.',
#  '2021, pp.',
#  '1–7, doi: 10.1109/ntms49979.2021.9432648.\n\n',
#  '[125] g. hou and l. chen, ‘‘d2d communication mode selection and resource\nallocation in 5g wireless networks,’’ comput.',
#  'commun., vol.',
#  '155,\npp.',
#  '244–251, apr.',
#  '2020, doi: 10.1016/j.comcom.2020.03.025.\n\n',
#  '[126] m. wang and z. yan, ‘‘a survey on security in d2d communica-\ntions,’’ mobile netw.',
#  'appl., vol.',
#  '22, no. 2, pp.',
#  '195–208, apr. 2017, doi:\n10.1007/s11036-016-0741-5.\n\n',
#  '[127] j. cao, m. ma, h. li, r. ma, y. sun, p. yu, and l. xiong,\n‘‘a survey on security aspects for 3gpp 5g networks,’’ ieee com-\nmun.',
#  'surveys tuts., vol.',
#  '22, no. 1, pp.',
#  '170–195, 1st quart., 2020, doi:\n10.1109/comst.2019.2951818.\n\n',
#  '[128] o. hayat, r. ngah, z. kaleem, s. z. m. hashim, and j. j. rodrigues,\n‘‘a survey on security and privacy challenges in device discovery for next-\ngeneration systems,’’ ieee access, vol. 8, pp.',
#  '84584–84603, 2020, doi:\n10.1109/access.2020.2991459.\n\n',
#  '[129] m. shih, ‘‘mobility management in d2d,’’ in wiley 5g ref, vol.',
#  '1.\n\nhoboken, nj, usa: wiley, 2019, pp.',
#  '1–22.\n\n',
#  '[130] t. d. hoang, l. b. le, and t. le-ngoc,\n\n‘‘joint mode selec-\ntion and resource allocation for relay-based d2d communications,’’\nieee commun.',
#  'lett., vol. 21, no. 2, pp.',
#  '398–401, feb. 2017, doi:\n10.1109/lcomm.2016.2617863.\n\nvolume 10, 2022\n\n30817\n\n\x0c[131] l. wang, h. tang, h. wu, and g. stüber, ‘‘resource allocation for\nd2d communications underlay in rayleigh fading channels,’’ ieee\ntrans.',
#  'veh. technol., vol.',
#  '66, no. 2, pp.',
#  '1159–1170, feb. 2017, doi:\n10.1109/tvt.2016.2553124.\n\n',
#  '[132] a. f. ashtiani and s. pierre, ‘‘power allocation and resource assignment\nfor secure d2d communication underlaying cellular networks: a tabu\nsearch approach,’’ comput.',
#  'netw., vol. 178, sep.',
#  '2020, art.',
#  'no. 107350,\ndoi: 10.1016/j.comnet.2020.107350.\n\n',
#  '[133] a. sultana, i. woungang, a. anpalagan, l. zhao, and l. ferdouse,\n‘‘efﬁcient resource allocation in scma-enabled device-to-device com-\nmunication for 5g networks,’’ ieee trans.',
#  'veh. technol., vol.',
#  '69, no. 5,\npp.',
#  '5343–5354, may 2020, doi: 10.1109/tvt.2020.2983569.\n\n',
#  '[134] m. k. pedhadiya, r. k. jha, and h. g. bhatt, ‘‘device to device communi-\ncation: a survey,’’ j. netw.',
#  'comput.',
#  'appl., vol.',
#  '129, pp.',
#  '71–89, nov. 2019,\ndoi: 10.1016/j.jnca.2018.10.012.\n\n',
#  '[135] r. zhang, c. qi, y. li, y. ruan, c.-x.',
#  'wang, and h. zhang, ‘‘towards\nenergy-efﬁcient underlaid device-to-device communications: a joint\nresource management approach,’’ ieee access, vol. 7, pp.',
#  '31385–31396,\n2019, doi: 10.1109/access.2019.2903214.\n\n',
#  '[136] j. wang, y. huang, s. jin, r. schober, x. you, and c. zhao, ‘‘resource\nmanagement for device-to-device communication: a physical\nlayer\nsecurity perspective,’’ ieee j. sel.',
#  'areas commun., vol.',
#  '36, no. 4,\npp.',
#  '946–960, apr.',
#  '2018, doi: 10.1109/jsac.2018.2825484.\n\n',
#  '[137] x. li, r. shankaran, m. a. orgun, g. fang, and y. xu, ‘‘resource\nallocation for underlay d2d communication with proportional fairness,’’\nieee trans.',
#  'veh. technol., vol.',
#  '67, no. 7, pp.',
#  '6244–6258, jul.',
#  '2018, doi:\n10.1109/tvt.2018.2817613.\n\n',
#  '[138] s. alemaishat, o. a. saraereh, i. khan, and b. j. choi, ‘‘an efﬁ-\ncient resource allocation algorithm for d2d communications based\non noma,’’ ieee access, vol. 7, pp.',
#  '120238–120247, 2019, doi:\n10.1109/access.2019.2937401.\n\n',
#  '[139] w.-k.',
#  'lai, y.-c.',
#  'wang, h.-c.',
#  'lin, and j.-w.',
#  'li, ‘‘efﬁcient resource\nallocation and power control for lte–a d2d communication with pure\nd2d model,’’ ieee trans.',
#  'veh. technol., vol.',
#  '69, no. 3, pp.',
#  '3202–3216,\nmar.',
#  '2020, doi: 10.1109/tvt.2020.2964286.\n\n',
#  '[140] l. wang, c. li, y. zhang, and g. gui, ‘‘game-theoretic social-\naware resource allocation for device-to-device communications under-\nlaying cellular network,’’ wireless commun.',
#  'mobile comput., vol.',
#  '2018,\npp.',
#  '1–12, 2018, doi: 10.1155/2018/5084842.\n\n',
#  '[141] j. huang, y. yin, y. zhao, q. duan, w. wang, and s. yu,\n‘‘a game-theoretic resource allocation approach for intercell device-\nto-device communications in cellular networks,’’ ieee trans.',
#  'emerg.\n',
#  'topics comput., vol.',
#  '4, no. 4, pp.',
#  '475–486, oct./dec.',
#  '2016, doi:\n10.1109/tetc.2014.2384372.\n\n',
#  '[142] p. mach, z. becvar, and m. najla, ‘‘resource allocation for d2d com-\nmunication with multiple d2d pairs reusing multiple channels,’’ ieee\nwireless commun.',
#  'lett., vol. 8, no. 4, pp.',
#  '1008–1011, aug. 2019, doi:\n10.1109/lwc.2019.2903798.\n\n',
#  '[143] b.-y.',
#  'huang, s.-t.',
#  'su, c.-y.',
#  'wang, c.-w.',
#  'yeh, and h.-y.',
#  'wei, ‘‘resource\nallocation in d2d communication–a game theoretic approach,’’ in proc.\n',
#  'ieee int.',
#  'conf.',
#  ...]

# %%
words
# Out:
# ['received',
#  'march',
#  '1',
#  ',',
#  '2022',
#  ',',
#  'accepted',
#  'march',
#  '14',
#  ',',
#  '2022',
#  ',',
#  'date',
#  'of',
#  'publication',
#  'march',
#  '16',
#  ',',
#  '2022',
#  ',',
#  'date',
#  'of',
#  'current',
#  'version',
#  'march',
#  '24',
#  ',',
#  '2022',
#  '.',
#  '\n\n',
#  'digital',
#  'object',
#  'identifier',
#  '10.1109',
#  '/',
#  'access.2022.3160215',
#  '\n\n',
#  'survey',
#  'on',
#  'device',
#  'to',
#  'device',
#  '(',
#  'd2d',
#  ')',
#  'communication',
#  '\n',
#  'for',
#  '5gb/6',
#  'g',
#  'networks',
#  ':',
#  'concept',
#  ',',
#  'applications',
#  ',',
#  '\n',
#  'challenges',
#  ',',
#  'and',
#  'future',
#  'directions',
#  '\n\n',
#  'mohammed',
#  'salih',
#  'mohammed',
#  'gismalla',
#  '1,2,3',
#  ',',
#  '(',
#  'senior',
#  'member',
#  ',',
#  'ieee',
#  ')',
#  ',',
#  '\n',
#  'asrul',
#  'izam',
#  'azmi',
#  '1,2',
#  ',',
#  '(',
#  'member',
#  ',',
#  'ieee',
#  ')',
#  ',',
#  'mohd',
#  'rashidi',
#  'bin',
#  'salim1,2',
#  ',',
#  '(',
#  'member',
#  ',',
#  'ieee',
#  ')',
#  ',',
#  '\n',
#  'mohammad',
#  'faiz',
#  'liew',
#  'abdullah',
#  '4',
#  ',',
#  '(',
#  'senior',
#  'member',
#  ',',
#  'ieee',
#  ')',
#  ',',
#  'farabi',
#  'iqbal1,2',
#  ',',
#  '\n',
#  'wafi',
#  'a.',
#  'mabrouk',
#  '4',
#  ',',
#  '(',
#  'graduate',
#  'student',
#  'member',
#  ',',
#  'ieee',
#  ')',
#  ',',
#  '\n',
#  'maisara',
#  'binti',
#  'othman4',
#  ',',
#  '(',
#  'member',
#  ',',
#  'ieee',
#  ')',
#  ',',
#  'adel',
#  'y.',
#  'i.',
#  'ashyap',
#  '4',
#  ',',
#  '\n',
#  'and',
#  'abu',
#  'sahmah',
#  'mohd',
#  'supa’at1,2',
#  '\n',
#  '1school',
#  'of',
#  'electrical',
#  'engineering',
#  ',',
#  'faculty',
#  'of',
#  'engineering',
#  ',',
#  'universiti',
#  'teknologi',
#  'malaysia',
#  ',',
#  'skudai',
#  '81310',
#  ',',
#  'malaysia',
#  '\n',
#  '2lightwave',
#  'communications',
#  'research',
#  'group',
#  '(',
#  'lcrg',
#  ')',
#  ',',
#  'innovative',
#  'engineering',
#  'research',
#  'alliance',
#  ',',
#  'universiti',
#  'teknologi',
#  'malaysia',
#  ',',
#  'johor',
#  'bahru',
#  '81310',
#  ',',
#  'malaysia',
#  '\n',
#  '3department',
#  'of',
#  'electronics',
#  'and',
#  'electrical',
#  'engineering',
#  ',',
#  'faculty',
#  'of',
#  'engineering',
#  ',',
#  'international',
#  'university',
#  'of',
#  'africa',
#  ',',
#  'khartoum',
#  '12223',
#  ',',
#  'sudan',
#  '\n',
#  '4department',
#  'of',
#  'communication',
#  'engineering',
#  ',',
#  'faculty',
#  'of',
#  'electrical',
#  'and',
#  'electronic',
#  'engineering',
#  ',',
#  'universiti',
#  'tun',
#  'hussein',
#  'onn',
#  'malaysia',
#  '(',
#  'uthm',
#  ')',
#  ',',
#  'parit',
#  'raja',
#  ',',
#  'batu',
#  '\n',
#  'pahat',
#  ',',
#  'johor',
#  '86400',
#  ',',
#  'malaysia',
#  '\n',
#  'corresponding',
#  'authors',
#  ':',
#  'mohammed',
#  'salih',
#  'mohammed',
#  'gismalla',
#  '(',
#  'salihmohammed@utm.my',
#  ')',
#  'and',
#  'abu',
#  'sahmah',
#  'mohd',
#  'supa’at',
#  '\n',
#  '(',
#  'abus@utm.my',
#  ')',
#  '\n\n',
#  'this',
#  'work',
#  'was',
#  'supported',
#  'in',
#  'part',
#  'by',
#  'the',
#  'research',
#  'management',
#  'centre',
#  '(',
#  'rmc',
#  ')',
#  ',',
#  'universiti',
#  'teknologi',
#  'malaysia',
#  '(',
#  'utm',
#  ')',
#  ',',
#  'malaysia',
#  ',',
#  'under',
#  'the',
#  '\n',
#  'professional',
#  'development',
#  'research',
#  'university',
#  'grant',
#  '05e69',
#  ';',
#  'and',
#  'in',
#  'part',
#  'by',
#  'utm',
#  'under',
#  'tdr',
#  'grant',
#  '05g27',
#  '.',
#  '\n\n',
#  'abstract',
#  'device',
#  '-',
#  'to',
#  '-',
#  'device',
#  '(',
#  'd2d',
#  ')',
#  'communication',
#  'is',
#  'one',
#  'of',
#  'the',
#  'most',
#  'promising',
#  'technologies',
#  'in',
#  'wireless',
#  '\n',
#  'cellular',
#  'networks',
#  'that',
#  'can',
#  'be',
#  'employed',
#  'to',
#  'improve',
#  'spectral',
#  'and',
#  'energy',
#  'efﬁciency',
#  ',',
#  'increase',
#  'data',
#  'rates',
#  ',',
#  'and',
#  '\n',
#  'reduce',
#  'links',
#  'latency',
#  '.',
#  'this',
#  'paper',
#  'investigates',
#  'ﬁfth',
#  'generation',
#  'and',
#  'beyond',
#  '(',
#  '5',
#  'gb',
#  ')',
#  'networks',
#  ',',
#  'the',
#  'basics',
#  'of',
#  '\n',
#  'd2d',
#  'communication',
#  ',',
#  'applications',
#  ',',
#  'and',
#  'classiﬁcation',
#  '.',
#  'herein',
#  ',',
#  'd2d',
#  'in',
#  'in',
#  '-',
#  'band',
#  '(',
#  'ibd',
#  ')',
#  'and',
#  'out',
#  '-',
#  'band',
#  '(',
#  'obd',
#  ')',
#  '\n',
#  'modes',
#  'are',
#  'discussed',
#  '.',
#  'this',
#  'paper',
#  'also',
#  'presents',
#  'the',
#  'integration',
#  'of',
#  'd2d',
#  'communication',
#  'with',
#  'other',
#  'prominent',
#  '\n',
#  'technologies',
#  'and',
#  'demonstrates',
#  'the',
#  'importance',
#  'of',
#  'integration',
#  'with',
#  'possible',
#  'solutions',
#  'in',
#  'improving',
#  'network',
#  '\n',
#  'performance',
#  '.',
#  'we',
#  'further',
#  'investigate',
#  'the',
#  'challenges',
#  'of',
#  'd2d',
#  'communication',
#  ',',
#  'opportunities',
#  ',',
#  'and',
#  'future',
#  '\n',
#  'research',
#  'directions',
#  'of',
#  'd2d',
#  'in',
#  '5',
#  'gb',
#  'networks',
#  '.',
#  'in',
#  'addition',
#  ',',
#  'd2d',
#  'communication',
#  'in',
#  '6',
#  'g',
#  'network',
#  'challenges',
#  '\n',
#  'and',
#  'open',
#  'research',
#  'areas',
#  'are',
#  'introduced',
#  '.',
#  '\n\n',
#  'index',
#  'terms',
#  '5',
#  'g',
#  ',',
#  '5',
#  'gb',
#  ',',
#  '6',
#  'g',
#  ',',
#  'd2d',
#  'communication',
#  ',',
#  'millimeter',
#  'wave',
#  '(',
#  'mm',
#  '-',
#  'wave',
#  ')',
#  ',',
#  'visible',
#  'light',
#  'communi-',
#  '\n',
#  'cation',
#  '(',
#  'vlc',
#  ')',
#  ',',
#  'ultra',
#  '-',
#  'dense',
#  'network',
#  '(',
#  'udn',
#  ')',
#  ',',
#  'and',
#  'unmanned',
#  'aerial',
#  'vehicle',
#  '(',
#  'uav',
#  ')',
#  '.',
#  '\n\n',
#  'i.',
#  'introduction',
#  '\n',
#  'mobile',
#  'wireless',
#  'communication',
#  'demands',
#  'for',
#  'higher',
#  'data',
#  '\n',
#  'rates',
#  ',',
#  'lower',
#  'energy',
#  'consumption',
#  ',',
#  'low',
#  'latency',
#  ',',
#  'coverage',
#  'area',
#  ',',
#  '\n',
#  'as',
#  'well',
#  'as',
#  'efﬁcient',
#  'spectrum',
#  'sharing',
#  'are',
#  'rapidly',
#  'increasing',
#  '\n',
#  'day',
#  'by',
#  'day',
#  '.',
#  'the',
#  'number',
#  'of',
#  'connected',
#  'devices',
#  'is',
#  'estimated',
#  '\n',
#  'to',
#  'be',
#  'over',
#  '50',
#  'billion',
#  'in',
#  'the',
#  'year',
#  '2020',
#  '[',
#  '1]–[3',
#  ']',
#  ',',
#  'in',
#  'which',
#  '\n',
#  'mobile',
#  'data',
#  'trafﬁc',
#  'is',
#  'projected',
#  'to',
#  'grow',
#  'monthly',
#  'from',
#  '13.8',
#  'in',
#  '\n',
#  '2017',
#  'to',
#  '110',
#  'exabytes',
#  '(',
#  'eb',
#  ')',
#  'till',
#  'the',
#  'end',
#  'of',
#  '2023',
#  'at',
#  'a',
#  'compound',
#  '\n',
#  'annual',
#  'growth',
#  'rate',
#  '(',
#  'cagr',
#  ')',
#  'of',
#  '42',
#  '%',
#  'based',
#  'on',
#  'the',
#  'ericsson',
#  '\n',
#  'report',
#  '[',
#  '4',
#  ']',
#  '.',
#  'all',
#  'these',
#  'issues',
#  'should',
#  'be',
#  'resolved',
#  'to',
#  'provide',
#  'and',
#  '\n',
#  'support',
#  'the',
#  'demands',
#  'of',
#  'the',
#  'upcoming',
#  'ﬁfth',
#  '-',
#  'generation',
#  '(',
#  '5',
#  'g',
#  ')',
#  '\n\n',
#  'the',
#  'associate',
#  'editor',
#  'coordinating',
#  'the',
#  'review',
#  'of',
#  'this',
#  'manuscript',
#  'and',
#  '\n\n',
#  'approving',
#  'it',
#  'for',
#  'publication',
#  'was',
#  'stefano',
#  'scanzio',
#  '\n\n',
#  '.',
#  '\n\n',
#  'and',
#  'beyond',
#  '(',
#  '5',
#  'gb',
#  ')',
#  '.',
#  '5',
#  'g',
#  'was',
#  'expected',
#  'to',
#  'launch',
#  'in',
#  '2020',
#  'with',
#  '\n',
#  'a',
#  'very',
#  'high',
#  'data',
#  'rate',
#  'and',
#  'quality',
#  'of',
#  'services',
#  '(',
#  'qos',
#  ')',
#  ',',
#  'and',
#  '\n',
#  'it',
#  'aims',
#  'to',
#  'offer',
#  'a',
#  '1000',
#  '-',
#  'fold',
#  'rise',
#  'in',
#  'the',
#  'total',
#  'throughput',
#  '.',
#  '\n',
#  'moreover',
#  ',',
#  'in',
#  'order',
#  'to',
#  'achieve',
#  'a',
#  'ten',
#  '-',
#  'fold',
#  'increase',
#  'in',
#  'indi-',
#  '\n',
#  'vidual',
#  'link',
#  'throughput',
#  'over',
#  'the',
#  'previous',
#  'fourth',
#  '-',
#  'generation',
#  '\n',
#  '(',
#  '4',
#  'g',
#  ')',
#  'wireless',
#  'networks',
#  '[',
#  '5',
#  ']',
#  ',',
#  '[',
#  '6',
#  ']',
#  ',',
#  'various',
#  'technologies',
#  'are',
#  '\n',
#  'suggested',
#  'to',
#  'be',
#  'considered',
#  'in',
#  'order',
#  'to',
#  'fulﬁll',
#  '5',
#  'gb',
#  'require-',
#  '\n',
#  'ments',
#  'such',
#  'as',
#  'an',
#  'ultra',
#  '-',
#  'dense',
#  'network',
#  '(',
#  'udn',
#  ')',
#  'with',
#  'machine-',
#  '\n',
#  'to',
#  '-',
#  'machine',
#  '(',
#  'm2',
#  'm',
#  ')',
#  'in',
#  'heterogeneous',
#  'networks',
#  ',',
#  'in',
#  'addition',
#  'to',
#  '\n',
#  'millimeter',
#  '-',
#  'wave',
#  '(',
#  'mm',
#  '-',
#  'wave',
#  ')',
#  ',',
#  'massive',
#  'mimo',
#  ',',
#  'virtualization',
#  '\n',
#  'of',
#  'wireless',
#  'resources',
#  ',',
#  'visible',
#  'light',
#  'communication',
#  '(',
#  'vlc',
#  ')',
#  ',',
#  '\n',
#  'energy',
#  'harvesting',
#  ',',
#  'and',
#  'cloud',
#  '-',
#  'based',
#  'radio',
#  'access',
#  'network',
#  '\n',
#  '(',
#  'c',
#  '-',
#  'ran',
#  ')',
#  '[',
#  '7',
#  ']',
#  '.',
#  'a',
#  'novel',
#  'physical',
#  'technology',
#  'such',
#  'as',
#  'vlc',
#  '\n',
#  'has',
#  'been',
#  'suggested',
#  'to',
#  'deliver',
#  'high',
#  'data',
#  'rates',
#  ',',
#  'where',
#  'a',
#  '\n\n',
#  '30792',
#  '\n\n',
#  'this',
#  'work',
#  'is',
#  'licensed',
#  'under',
#  'a',
#  'creative',
#  'commons',
#  'attribution',
#  '4.0',
#  'license',
#  '.',
#  'for',
#  'more',
#  'information',
#  ',',
#  'see',
#  'https://creativecommons.org/licenses/by/4.0/',
#  '\n\n',
#  'volume',
#  '10',
#  ',',
#  '2022',
#  '\n\n\x0c',
#  'm.',
#  's.',
#  'm.',
#  'gismalla',
#  'et',
#  'al',
#  '.',
#  ':',
#  'survey',
#  'on',
#  'd2d',
#  'communication',
#  'for',
#  '5gb/6',
#  'g',
#  'networks',
#  '\n\n',
#  'figure',
#  '1',
#  '.',
#  'developments',
#  'of',
#  'mobile',
#  'radio',
#  'communication',
#  'networks',
#  'generations',
#  '[',
#  '5',
#  ']',
#  '.',
#  '\n\n',
#  'considerable',
#  'bandwidth',
#  'of',
#  'vlc',
#  'technology',
#  'could',
#  'support',
#  '\n',
#  'higher',
#  'data',
#  'rates',
#  'with',
#  'up',
#  'to',
#  '100gbps',
#  'and',
#  'beyond',
#  '[',
#  '8]–[10',
#  ']',
#  '.',
#  '\n',
#  'fig.1',
#  'illustrates',
#  'the',
#  'development',
#  'of',
#  'mobile',
#  'communication',
#  '\n',
#  'networks',
#  ',',
#  'which',
#  'involves',
#  '1',
#  'g',
#  'to',
#  '5',
#  'g',
#  'generations',
#  ',',
#  'technolo-',
#  '\n',
#  'gies',
#  ',',
#  'systems',
#  ',',
#  'and',
#  'standardizations',
#  '.',
#  '\n\n',
#  'many',
#  'techniques',
#  'and',
#  'approaches',
#  'have',
#  'been',
#  'implemented',
#  '\n',
#  'to',
#  'cope',
#  'with',
#  'the',
#  'increasing',
#  'demand',
#  'for',
#  'network',
#  'capacity',
#  '.',
#  ...]

# %%
def remove_stop_words(words):
    # Load the list of English stop words
    stop_words = spacy.lang.en.stop_words.STOP_WORDS
    # Use a regular expression to remove the stop words from the list of words
    filtered_words = [word for word in words if word not in stop_words]
    return filtered_words
filtered_words = remove_stop_words(words)

# %%
filtered_words
# Out:
# ['received',
#  'march',
#  '1',
#  ',',
#  '2022',
#  ',',
#  'accepted',
#  'march',
#  '14',
#  ',',
#  '2022',
#  ',',
#  'date',
#  'publication',
#  'march',
#  '16',
#  ',',
#  '2022',
#  ',',
#  'date',
#  'current',
#  'version',
#  'march',
#  '24',
#  ',',
#  '2022',
#  '.',
#  '\n\n',
#  'digital',
#  'object',
#  'identifier',
#  '10.1109',
#  '/',
#  'access.2022.3160215',
#  '\n\n',
#  'survey',
#  'device',
#  'device',
#  '(',
#  'd2d',
#  ')',
#  'communication',
#  '\n',
#  '5gb/6',
#  'g',
#  'networks',
#  ':',
#  'concept',
#  ',',
#  'applications',
#  ',',
#  '\n',
#  'challenges',
#  ',',
#  'future',
#  'directions',
#  '\n\n',
#  'mohammed',
#  'salih',
#  'mohammed',
#  'gismalla',
#  '1,2,3',
#  ',',
#  '(',
#  'senior',
#  'member',
#  ',',
#  'ieee',
#  ')',
#  ',',
#  '\n',
#  'asrul',
#  'izam',
#  'azmi',
#  '1,2',
#  ',',
#  '(',
#  'member',
#  ',',
#  'ieee',
#  ')',
#  ',',
#  'mohd',
#  'rashidi',
#  'bin',
#  'salim1,2',
#  ',',
#  '(',
#  'member',
#  ',',
#  'ieee',
#  ')',
#  ',',
#  '\n',
#  'mohammad',
#  'faiz',
#  'liew',
#  'abdullah',
#  '4',
#  ',',
#  '(',
#  'senior',
#  'member',
#  ',',
#  'ieee',
#  ')',
#  ',',
#  'farabi',
#  'iqbal1,2',
#  ',',
#  '\n',
#  'wafi',
#  'a.',
#  'mabrouk',
#  '4',
#  ',',
#  '(',
#  'graduate',
#  'student',
#  'member',
#  ',',
#  'ieee',
#  ')',
#  ',',
#  '\n',
#  'maisara',
#  'binti',
#  'othman4',
#  ',',
#  '(',
#  'member',
#  ',',
#  'ieee',
#  ')',
#  ',',
#  'adel',
#  'y.',
#  'i.',
#  'ashyap',
#  '4',
#  ',',
#  '\n',
#  'abu',
#  'sahmah',
#  'mohd',
#  'supa’at1,2',
#  '\n',
#  '1school',
#  'electrical',
#  'engineering',
#  ',',
#  'faculty',
#  'engineering',
#  ',',
#  'universiti',
#  'teknologi',
#  'malaysia',
#  ',',
#  'skudai',
#  '81310',
#  ',',
#  'malaysia',
#  '\n',
#  '2lightwave',
#  'communications',
#  'research',
#  'group',
#  '(',
#  'lcrg',
#  ')',
#  ',',
#  'innovative',
#  'engineering',
#  'research',
#  'alliance',
#  ',',
#  'universiti',
#  'teknologi',
#  'malaysia',
#  ',',
#  'johor',
#  'bahru',
#  '81310',
#  ',',
#  'malaysia',
#  '\n',
#  '3department',
#  'electronics',
#  'electrical',
#  'engineering',
#  ',',
#  'faculty',
#  'engineering',
#  ',',
#  'international',
#  'university',
#  'africa',
#  ',',
#  'khartoum',
#  '12223',
#  ',',
#  'sudan',
#  '\n',
#  '4department',
#  'communication',
#  'engineering',
#  ',',
#  'faculty',
#  'electrical',
#  'electronic',
#  'engineering',
#  ',',
#  'universiti',
#  'tun',
#  'hussein',
#  'onn',
#  'malaysia',
#  '(',
#  'uthm',
#  ')',
#  ',',
#  'parit',
#  'raja',
#  ',',
#  'batu',
#  '\n',
#  'pahat',
#  ',',
#  'johor',
#  '86400',
#  ',',
#  'malaysia',
#  '\n',
#  'corresponding',
#  'authors',
#  ':',
#  'mohammed',
#  'salih',
#  'mohammed',
#  'gismalla',
#  '(',
#  'salihmohammed@utm.my',
#  ')',
#  'abu',
#  'sahmah',
#  'mohd',
#  'supa’at',
#  '\n',
#  '(',
#  'abus@utm.my',
#  ')',
#  '\n\n',
#  'work',
#  'supported',
#  'research',
#  'management',
#  'centre',
#  '(',
#  'rmc',
#  ')',
#  ',',
#  'universiti',
#  'teknologi',
#  'malaysia',
#  '(',
#  'utm',
#  ')',
#  ',',
#  'malaysia',
#  ',',
#  '\n',
#  'professional',
#  'development',
#  'research',
#  'university',
#  'grant',
#  '05e69',
#  ';',
#  'utm',
#  'tdr',
#  'grant',
#  '05g27',
#  '.',
#  '\n\n',
#  'abstract',
#  'device',
#  '-',
#  '-',
#  'device',
#  '(',
#  'd2d',
#  ')',
#  'communication',
#  'promising',
#  'technologies',
#  'wireless',
#  '\n',
#  'cellular',
#  'networks',
#  'employed',
#  'improve',
#  'spectral',
#  'energy',
#  'efﬁciency',
#  ',',
#  'increase',
#  'data',
#  'rates',
#  ',',
#  '\n',
#  'reduce',
#  'links',
#  'latency',
#  '.',
#  'paper',
#  'investigates',
#  'ﬁfth',
#  'generation',
#  '(',
#  '5',
#  'gb',
#  ')',
#  'networks',
#  ',',
#  'basics',
#  '\n',
#  'd2d',
#  'communication',
#  ',',
#  'applications',
#  ',',
#  'classiﬁcation',
#  '.',
#  ',',
#  'd2d',
#  '-',
#  'band',
#  '(',
#  'ibd',
#  ')',
#  '-',
#  'band',
#  '(',
#  'obd',
#  ')',
#  '\n',
#  'modes',
#  'discussed',
#  '.',
#  'paper',
#  'presents',
#  'integration',
#  'd2d',
#  'communication',
#  'prominent',
#  '\n',
#  'technologies',
#  'demonstrates',
#  'importance',
#  'integration',
#  'possible',
#  'solutions',
#  'improving',
#  'network',
#  '\n',
#  'performance',
#  '.',
#  'investigate',
#  'challenges',
#  'd2d',
#  'communication',
#  ',',
#  'opportunities',
#  ',',
#  'future',
#  '\n',
#  'research',
#  'directions',
#  'd2d',
#  '5',
#  'gb',
#  'networks',
#  '.',
#  'addition',
#  ',',
#  'd2d',
#  'communication',
#  '6',
#  'g',
#  'network',
#  'challenges',
#  '\n',
#  'open',
#  'research',
#  'areas',
#  'introduced',
#  '.',
#  '\n\n',
#  'index',
#  'terms',
#  '5',
#  'g',
#  ',',
#  '5',
#  'gb',
#  ',',
#  '6',
#  'g',
#  ',',
#  'd2d',
#  'communication',
#  ',',
#  'millimeter',
#  'wave',
#  '(',
#  'mm',
#  '-',
#  'wave',
#  ')',
#  ',',
#  'visible',
#  'light',
#  'communi-',
#  '\n',
#  'cation',
#  '(',
#  'vlc',
#  ')',
#  ',',
#  'ultra',
#  '-',
#  'dense',
#  'network',
#  '(',
#  'udn',
#  ')',
#  ',',
#  'unmanned',
#  'aerial',
#  'vehicle',
#  '(',
#  'uav',
#  ')',
#  '.',
#  '\n\n',
#  'i.',
#  'introduction',
#  '\n',
#  'mobile',
#  'wireless',
#  'communication',
#  'demands',
#  'higher',
#  'data',
#  '\n',
#  'rates',
#  ',',
#  'lower',
#  'energy',
#  'consumption',
#  ',',
#  'low',
#  'latency',
#  ',',
#  'coverage',
#  'area',
#  ',',
#  '\n',
#  'efﬁcient',
#  'spectrum',
#  'sharing',
#  'rapidly',
#  'increasing',
#  '\n',
#  'day',
#  'day',
#  '.',
#  'number',
#  'connected',
#  'devices',
#  'estimated',
#  '\n',
#  '50',
#  'billion',
#  'year',
#  '2020',
#  '[',
#  '1]–[3',
#  ']',
#  ',',
#  '\n',
#  'mobile',
#  'data',
#  'trafﬁc',
#  'projected',
#  'grow',
#  'monthly',
#  '13.8',
#  '\n',
#  '2017',
#  '110',
#  'exabytes',
#  '(',
#  'eb',
#  ')',
#  'till',
#  'end',
#  '2023',
#  'compound',
#  '\n',
#  'annual',
#  'growth',
#  'rate',
#  '(',
#  'cagr',
#  ')',
#  '42',
#  '%',
#  'based',
#  'ericsson',
#  '\n',
#  'report',
#  '[',
#  '4',
#  ']',
#  '.',
#  'issues',
#  'resolved',
#  'provide',
#  '\n',
#  'support',
#  'demands',
#  'upcoming',
#  'ﬁfth',
#  '-',
#  'generation',
#  '(',
#  '5',
#  'g',
#  ')',
#  '\n\n',
#  'associate',
#  'editor',
#  'coordinating',
#  'review',
#  'manuscript',
#  '\n\n',
#  'approving',
#  'publication',
#  'stefano',
#  'scanzio',
#  '\n\n',
#  '.',
#  '\n\n',
#  '(',
#  '5',
#  'gb',
#  ')',
#  '.',
#  '5',
#  'g',
#  'expected',
#  'launch',
#  '2020',
#  '\n',
#  'high',
#  'data',
#  'rate',
#  'quality',
#  'services',
#  '(',
#  'qos',
#  ')',
#  ',',
#  '\n',
#  'aims',
#  'offer',
#  '1000',
#  '-',
#  'fold',
#  'rise',
#  'total',
#  'throughput',
#  '.',
#  '\n',
#  ',',
#  'order',
#  'achieve',
#  '-',
#  'fold',
#  'increase',
#  'indi-',
#  '\n',
#  'vidual',
#  'link',
#  'throughput',
#  'previous',
#  'fourth',
#  '-',
#  'generation',
#  '\n',
#  '(',
#  '4',
#  'g',
#  ')',
#  'wireless',
#  'networks',
#  '[',
#  '5',
#  ']',
#  ',',
#  '[',
#  '6',
#  ']',
#  ',',
#  'technologies',
#  '\n',
#  'suggested',
#  'considered',
#  'order',
#  'fulﬁll',
#  '5',
#  'gb',
#  'require-',
#  '\n',
#  'ments',
#  'ultra',
#  '-',
#  'dense',
#  'network',
#  '(',
#  'udn',
#  ')',
#  'machine-',
#  '\n',
#  '-',
#  'machine',
#  '(',
#  'm2',
#  'm',
#  ')',
#  'heterogeneous',
#  'networks',
#  ',',
#  'addition',
#  '\n',
#  'millimeter',
#  '-',
#  'wave',
#  '(',
#  'mm',
#  '-',
#  'wave',
#  ')',
#  ',',
#  'massive',
#  'mimo',
#  ',',
#  'virtualization',
#  '\n',
#  'wireless',
#  'resources',
#  ',',
#  'visible',
#  'light',
#  'communication',
#  '(',
#  'vlc',
#  ')',
#  ',',
#  '\n',
#  'energy',
#  'harvesting',
#  ',',
#  'cloud',
#  '-',
#  'based',
#  'radio',
#  'access',
#  'network',
#  '\n',
#  '(',
#  'c',
#  '-',
#  'ran',
#  ')',
#  '[',
#  '7',
#  ']',
#  '.',
#  'novel',
#  'physical',
#  'technology',
#  'vlc',
#  '\n',
#  'suggested',
#  'deliver',
#  'high',
#  'data',
#  'rates',
#  ',',
#  '\n\n',
#  '30792',
#  '\n\n',
#  'work',
#  'licensed',
#  'creative',
#  'commons',
#  'attribution',
#  '4.0',
#  'license',
#  '.',
#  'information',
#  ',',
#  'https://creativecommons.org/licenses/by/4.0/',
#  '\n\n',
#  'volume',
#  '10',
#  ',',
#  '2022',
#  '\n\n\x0c',
#  'm.',
#  's.',
#  'm.',
#  'gismalla',
#  'et',
#  'al',
#  '.',
#  ':',
#  'survey',
#  'd2d',
#  'communication',
#  '5gb/6',
#  'g',
#  'networks',
#  '\n\n',
#  'figure',
#  '1',
#  '.',
#  'developments',
#  'mobile',
#  'radio',
#  'communication',
#  'networks',
#  'generations',
#  '[',
#  '5',
#  ']',
#  '.',
#  '\n\n',
#  'considerable',
#  'bandwidth',
#  'vlc',
#  'technology',
#  'support',
#  '\n',
#  'higher',
#  'data',
#  'rates',
#  '100gbps',
#  '[',
#  '8]–[10',
#  ']',
#  '.',
#  '\n',
#  'fig.1',
#  'illustrates',
#  'development',
#  'mobile',
#  'communication',
#  '\n',
#  'networks',
#  ',',
#  'involves',
#  '1',
#  'g',
#  '5',
#  'g',
#  'generations',
#  ',',
#  'technolo-',
#  '\n',
#  'gies',
#  ',',
#  'systems',
#  ',',
#  'standardizations',
#  '.',
#  '\n\n',
#  'techniques',
#  'approaches',
#  'implemented',
#  '\n',
#  'cope',
#  'increasing',
#  'demand',
#  'network',
#  'capacity',
#  '.',
#  '\n',
#  'new',
#  'modulation',
#  'techniques',
#  ',',
#  'signal',
#  'processing',
#  ',',
#  'spectrum',
#  '\n',
#  'allocation',
#  'techniques',
#  'employed',
#  'improve',
#  'spectral',
#  'efﬁ-',
#  '\n',
#  'ciency',
#  'link',
#  'capacity',
#  '.',
#  ',',
#  'require',
#  'small',
#  '\n',
#  'base',
#  'stations',
#  'indoor',
#  'environments',
#  'order',
#  'meet',
#  '\n',
#  'requirements',
#  'upcoming',
#  '5',
#  'gb',
#  'applications',
#  ',',
#  '\n',
#  'improving',
#  'channel',
#  'capacity',
#  ',',
#  'transmission',
#  'rate',
#  ',',
#  'bit',
#  'error',
#  '\n',
#  'rate',
#  '(',
#  'ber',
#  ')',
#  'performance',
#  'signal',
#  '-',
#  '-',
#  'noise',
#  '(',
#  'snr',
#  ')',
#  ',',
#  '\n',
#  'increase',
#  'total',
#  'spectral',
#  'efﬁciency',
#  'bandwidth',
#  'den-',
#  '\n',
#  'sity',
#  '[',
#  '11',
#  ']',
#  ',',
#  '[',
#  '12',
#  ']',
#  '.',
#  '\n\n',
#  'according',
#  'current',
#  'expected',
#  'requirements',
#  '\n',
#  'communication',
#  'networks',
#  ',',
#  'emerging',
#  'technology',
#  'called',
#  '\n',
#  'device',
#  '-',
#  '-',
#  'device',
#  '(',
#  'd2d',
#  ')',
#  'communication',
#  'attracted',
#  'atten-',
#  '\n',
#  'tion',
#  'critical',
#  'key',
#  'cellular',
#  'network',
#  'performance',
#  '\n',
#  'enhancement',
#  '5',
#  'gb',
#  '[',
#  '13',
#  ']',
#  ',',
#  '[',
#  '14',
#  ']',
#  '.',
#  'd2d',
#  'communication',
#  'offers',
#  '\n',
#  'advantages',
#  'cellular',
#  'networks',
#  ',',
#  ';',
#  '(',
#  ')',
#  'higher',
#  '\n',
#  'transmission',
#  'rate',
#  ',',
#  '(',
#  'ii',
#  ')',
#  'enhancing',
#  'energy',
#  'efﬁciency',
#  ',',
#  '(',
#  'iii',
#  ')',
#  '\n',
#  'ofﬂoading',
#  'overloaded',
#  'cellular',
#  'trafﬁc',
#  ',',
#  '(',
#  'iv',
#  ')',
#  'wide',
#  'cellular',
#  '\n',
#  'coverage',
#  ',',
#  '(',
#  'v',
#  ')',
#  'reducing',
#  'delay',
#  'latency',
#  ',',
#  '(',
#  'vi',
#  ')',
#  'higher',
#  'spec-',
#  '\n',
#  'tral',
#  'efﬁciency',
#  '[',
#  '15]–[18',
#  ']',
#  '.',
#  'd2d',
#  'communication',
#  '\n',
#  'ﬁelds',
#  ',',
#  'public',
#  'safety',
#  ',',
#  'network',
#  'trafﬁc',
#  'ofﬂoad-',
#  '\n',
#  'ing',
#  ',',
#  'military',
#  'applications',
#  ',',
#  'social',
#  'services',
#  ',',
#  'gaming',
#  ...]
